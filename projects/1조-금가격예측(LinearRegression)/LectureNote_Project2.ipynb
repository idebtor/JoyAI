# %% [markdown]
# # LectureNote: Project - 2
#
#
# # Project - 선형회귀를 활용한 배추가격 예측 AI 개발 (1 ~ 7강)

# %% [markdown]
# ### 추천의 말
# 여기에 소개하는 "안경잡이 개발자(동빈나)" 강의는 최근(2018)에 만들어지고, 우리의 교육과정의 일부분으로 적합하여 여러분에게 수강을 추천합니다. 모든 동영상 강의가 유튜브에 공개되어 있을 뿐만 아니라 [naver blog](https://blog.naver.com/ndb796/221036493985)에는 스크립트와 함께 동영상을 볼 수 있습니다.
#
# 본 프로젝트도 동빈나 강의자가 유튜브에 1강부터 7강까지로 소개하고 있습니다. 아래와 같이 자료들과 깃허브 소스도 제공하고 있으니 참고하길 바랍니다.
#
# - [블로그와 자료](https://ndb796.tistory.com/124?category=1013932)
#
# - [깃허브 자료와 소스](https://github.com/ndb796/Vegita/blob/master/README.md)
#
# - [웹서버 부트스트랩](https://mdbootstrap.com/freebies/jquery/full-page-video-carousel/)
#
# #### 1. [프로젝트 개요](https://www.youtube.com/watch?v=wZvhBVqitn8&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=13) (4:30)
#
# #### 2. [프로젝트 아이디어 결정 및 데이터 수집](https://www.youtube.com/watch?v=86u8TmkRN38&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=14) (4:46)
#
# #### 3. [다변인 선형회귀 모델 개발하기](https://www.youtube.com/watch?v=9Ur7bbZtoTc&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=15) (8:44)
#
# #### 4. [저장된 학습 모델로 배추 가격 예측하기](https://www.youtube.com/watch?v=xJuW_DltmDE&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=16) (4:09)
#
# #### 5. [기초 데이터 시각화하기](https://www.youtube.com/watch?v=EtW6c8W_cnw&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=17) (3:32)
#
# #### 6. [플라스크 웹 서버와 웹 디자인](https://www.youtube.com/watch?v=gmbkKE-jUUE&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=18) (6:21)
#
# #### 7. [플라스크와 텐서플로우 연동하기](https://www.youtube.com/watch?v=gmbkKE-jUUE&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=18) (5:44)

# %% [markdown]
# # 4강 저장된 학습 모델로 배추 가격 예측하기

# %%
import tensorflow as tf
import numpy as np

# %%
# 플레이스 홀더를 설정합니다.

X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")

# %%
# 가설을 설정합니다.

hypothesis = tf.matmul(X, W) + b

# %%
# 저장된 모델을 불러오는 객체를 선언합니다.

saver = tf.train.Saver()
model = tf.global_variables_initializer()

# %%
# 4가지 변수를 입력 받습니다.

avg_temp = float(input('평균 온도: '))
min_temp = float(input('최저 온도: '))
max_temp = float(input('최고 온도: '))
rain_fall = float(input('강수량: '))
# Out:
# 평균 온도: 15.5
# 최저 온도: 3.5
# 최고 온도: 20.5
# 강수량: 10

# %%
with tf.Session() as sess:
    sess.run(model)



    # 저장된 학습 모델을 파일로부터 불러옵니다.

    save_path = "./saved.cpkt"
    saver.restore(sess, save_path)


    # 사용자의 입력 값을 이용해 배열을 만듭니다.

    data = ((avg_temp, min_temp, max_temp, rain_fall), )
    arr = np.array(data, dtype=np.float32)

    # 예측을 수행한 뒤에 그 결과를 출력합니다.

    x_data = arr[0:4]
    dict = sess.run(hypothesis, feed_dict={X: x_data})
    print(dict[0])
# Out:
# WARNING:tensorflow:From C:\Users\kjb13\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./saved.cpkt
# [4708.2515]

# %% [markdown]
# # 제 5 강 데이터 시각화

# %% [markdown]
# # 제 6 강 플라스크 웹 서버와 웹 디자인 구현하기

# %%
# -*- coding: utf-8 -*-

from flask import Flask, render_template, request

app = Flask(__name__)

@app.route("/", methods=['GET', 'POST'])

def index():
        return render_template('index.html')

if __name__ == '__main__':
   app.run(debug = True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with stat
# ERROR! Session/line number was not unique in database. History logging moved to new session 111
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %% [markdown]
# # 제 7 강 플라스크와 텐서플로우 연동하기

# %%
# -*- coding: utf-8 -*-

from flask import Flask, render_template, request

import datetime
import tensorflow as tf
import numpy as np

app = Flask(__name__)


# 플레이스 홀더를 설정합니다.

X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")


# 가설을 설정합니다.

hypothesis = tf.matmul(X, W) + b

# 저장된 모델을 불러오는 객체를 선언합니다.

saver = tf.train.Saver()
model = tf.global_variables_initializer()


# 세션 객체를 생성합니다.

sess = tf.Session()
sess.run(model)


# 저장된 모델을 세션에 적용합니다.

save_path = "./model/saved.cpkt"
saver.restore(sess, save_path)


@app.route("/", methods=['GET', 'POST'])

def index():
    if request.method == 'GET':
        return render_template('index.html')

    if request.method == 'POST':
        # 파라미터를 전달 받습니다.

        avg_temp = float(request.form['avg_temp'])
        min_temp = float(request.form['min_temp'])
        max_temp = float(request.form['max_temp'])
        rain_fall = float(request.form['rain_fall'])


        # 배추 가격 변수를 선언합니다.

        price = 0

        # 입력된 파라미터를 배열 형태로 준비합니다.

        data = ((avg_temp, min_temp, max_temp, rain_fall), (0, 0, 0, 0))
        arr = np.array(data, dtype=np.float32)


        # 입력 값을 토대로 예측 값을 찾아냅니다.

        x_data = arr[0:4]
        dict = sess.run(hypothesis, feed_dict={X: x_data})


        # 결과 배추 가격을 저장합니다.

        price = dict[0]

        return render_template('index.html', price=price)



if __name__ == '__main__':
   app.run(debug = True)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 112

# %% [markdown]
# Pro1&2 김정빈 (21400179)
#
# # 다변인 선형회귀를 활용한 배추 가격 예측 AI 개발하기
#
# ## 프로젝트 개요
#
# 단순히 인공지능 학습 모델만 개발하는 것이 아니라 웹 서버 개발 과정까지 포함하여 ‘인공지능이 들어간 상용 서비스를 만들 수 있을까?’에 대해서까지 인사이트를 제공한다.
# ‘파이썬, 텐서플로우, 학습 모델 저장 및 불러오기, 플라스크 웹 서버, MDBootstrap 디자인 프레임워크, 클라우드 호스팅 서비스’ 기술을 다룬다.
#
# ------
#
# ## 프로젝트 아이디어 및 데이터 수집
#
# 다변인 선형회귀는 데이터를 예측할 때 사용할 수 있는 대표적인 모델이다.
# 데이터 수집 : 기후 데이터와 배추 가격 데이터는 무료로 제공된다. 다만 각 서비스는 데이터를 제공하는 정책이 다를 수 있기 때문에 필요에 따라서 크롤링(Crawling)의 과정이 필요할 수도 있다.
# 데이터 정제 : 수집한 데이터는 인공지능 소프트웨어가 인식하기 쉬운 형태로 정제해야 한다.
#
# ------
#
# ## 다변인 선형회귀 모델 개발하기
#
# 다변인 선형회귀는 모델에 영향을 미치는 변인이 여러 개 일 때 사용하는 모델이다. 현재 데이터에서는 변인이 ‘평균 온도’, ‘최저 온도’, ‘최고 온도’, ‘강수량’이므로 이 모든 변인이 ‘가격’에 영향을 미친다고 감안해야 한다. 따라서 가중치(Weight)를 고려했을 때 다음과 같은 수식을 세울 수 있다.
# H(x1, x2, x3, x4) = x1w1 + x2w2 + x3w3 + x4w4
# 이는 행렬의 곱을 이용하면 H(X) = XW 로 간단하게 표현할 수 있다.
# 이를 소스코드에 그대로 옮기면 된다. 다만 학습의 보폭(Step)을 적절히 선택해야 안정적으로 학습이 가능할 것이다. 프로젝트에서는 학습률을 0.000005로 설정하여 되도록 짧은 시간에 정확한 결과가 나오도록 구현했다.
# 결과적으로 향후 사용자가 날씨 정보를 입력했을 때 배추 가격을 바로 보여줄 수 있도록 학습 모델이 파일 형태로 저장된다.
#
#
# ------
#
# ## 저장된 학습 모델로 배추 가격 예측하기
#
# 학습 모델을 저장하는 이유는 만약 학습 모델을 저장하지 않고 사용자로부터 배추 가격 요청이 발생할 때마다 매 번 학습해서 결과를 올려준다면 시간이 오래 걸리고 많은 리소스가 소모될 것이다. 따라서 오프라인에서 주기적으로 데이터를 이용해 학습을 진행한 뒤에, 그 결과를 저장해서 서버에서는 실시간 요청에 따라 이미 저장된 학습 모델로 배추 가격을 예측하는 것이 효율적이다.
#
# ------
#
# ## 기초 데이터 시각화하기
#
# 다양한 데이터를 수집해서 인공지능 모델을 돌려 보아도 입력 값과 결과 값의 상관 관계를 찾아내는 것은 쉽지 않을 수 있다. 그래서 만약 많은 시행 착오를 거치고 있는 상황이라면 다양한 데이터를 수집해 보고, 데이터 시각화를 통해서 상관 관계를 유추하는 방법이 사용될 수도 있다. 특히 데이터의 개수가 많을 때는 한 눈에 데이터가 보이지 않을 수 있으므로 유용한 방법이 될 수 있다.
#
# ------
#
# ## 플라스크 웹 서버와 웹 디자인 구현하기
#
# 만든 학습 모델을 이용하기 위해 가장 먼저 플라스크(Flask) 웹 서버를 구축하고 웹 디자인 작업을 해주도록 한다.
# 다른 사용자들이 우리가 만든 웹 사이트를 볼 수 있도록 하기 위해서 플라스크(Flask) 웹 서버를 만든다. 플라스크는 파이썬 기반의 웹 서버 프레임워크이다. 따라서 server.py 소스코드를 생성해준다.
# 기본적으로 플라스크(Flask)는 static 폴더와 templates 폴더 안에 웹 문서 파일을 넣도록 되어 있다. Templates 폴더 안에 index.html 파일을 넣고, 기타 디자인 파일은 static 폴더 안에 넣는다.
#
# ------
#
# ## 플라스크와 텐서플로우 연동하기
#
# 플라스크 웹 서버에 텐서플로우 기반의 학습 모델을 이용해 배추 가격 예측하는 서버 기능을 삽입한다.
# 가장 먼저 사용자로부터 ‘평균 온도’, ‘최소 온도’, ‘최대 온도’, ‘강수량’을 입력 받을 수 있도록 웹 클라이언트 HTML 소스코드를 변경한다. <form> 태그를 이용하면 플라스크 웹 서버에서 처리할 수 있도록 손쉽게 파라미터를 전달할 수 있다.
# 플라스크 웹 서버의 루트 폴더에 ‘model’ 폴더를 생성하여 학습 모델이 담길 수 있도록 한다.
# 그리고 사용자로부터 배추 가격 예측 요청이 들어오면 그 결과를 반환하도록 서버 소스코드를 수정한다.
# 서버 소스코드를 수정한 이후에는 다시 서버를 재구동하면 된다. 혹시 ‘UTF-8’ 인코딩 관련 오류가 발생한다면 다음과 같이 서버 소스코드 파일을 ‘UTF-8’ 인코딩으로 저장한다.
# 완성된 프로젝트를 테스트 하기 위해 서버를 구동시킨다.
#
# -----
#
# # Project 1 & 2
#
# Project 1 & 2: `Name:__________ Nickname:__________`
#
# ------
#
# **Question 1**:
#
# 프로젝트에서 다루게 될 기술이 아닌 것은?
#
# ```
#
# (1) 파이썬(Python)  (2) 텐서플로우(Tensorflow)  (3) 플라스크(Flask) 웹 서버  (4) Java Script
#
# ```
#
# **Answer : (4)**
#
#
# **Question 2**:
#
# 수집한 데이터를 인공지능 소프트웨어가 인식하기 쉬운 형태로 수정하는 것을 무엇이라 하는가?
#
# ```
#
# (1) 데이터 처리  (2) 데이터 정제  (3) 데이터 수정  (4) 데이터 분리
#
# ```
#
# **Answer : (2)**
#
#
# **Question 3**:
#
# 다변인 선형회귀에서 가중치(Weight)를 고려하여 세울 수 있는 수식은?
#
# ```
#
# (1)	H(x1, x2, x3, x4) = x1w1 + x2w2 + x3w3 + x4w4
# (2)	Y = a*X + b
# (3)	H = X*W + a
# (4)	H = X*a + W
#
# ```
#
# **Answer : (1)**
#
#
#
# **Question 4**:
#
# 선형 회귀 모델을
# saver = tf.train.Saver()
# save_path = saver.save(sess, "./saved.cpkt")
# 으로 저장 시 생성되는 파일이 아닌 것은?
#
# ```
#
# (1) checkpoint  (2) saved.cpkt.meta  (3) price data.csv  (4) saved.cpkt.index
#
# ```
#
# **Answer : (3)**
#
#
# **Question 5**:
#
# 학습 모델을 저장하는 이유는?
#
# ```
#
# (1) 코드가 길어기지 때문이다.  (2) 예측 실패를 방지하기 위함이다.  (3) 요청 때마다 학습해서 결과를 돌려준다면 시간이 오래 걸린다.  (4) 많은 리소스가 소모되는 것을 방지하기 위함이다
#
# ```
#
# **Answer : (3), (4)**
#
#
# **Question 6**
#
# 데이터 시각화의 필요성으로 바른 것은?
#
# ```
#
# (1) 입력 값과 결과 값의 상관 관계를 찾아낸다.
# (2) 디자인적으로 보기 좋도록 한다.
# (3) 데이터 처리를 빠르게 한다.
# (4) 데이터 정제를 깔끔하게 한다.
#
# ```
#
# **Answer : (1)**
#
#
# **Question 7**
#
# 기본적으로 플라스크(Flask)는 어떤 폴더 안에 웹 문서 파일을 넣도록 되어 있는가? (두 가지)
#
# ```
#
# (1) static 폴더 (2) python 폴더
# (3) Anaconda3 폴더  (4) templates 폴더
#
# ```
#
# **Answer : (1), (4)**
#
#
# **Question 8**
#
# 기본적으로 플라스크(Flask)는 어떤 폴더 안에 웹 문서 파일을 넣도록 되어 있는가? (두 가지)
#
# ```
#
# (1) static 폴더 (2) python 폴더
# (3) Anaconda3 폴더  (4) templates 폴더
#
# ```
#
# **Answer : (1), (4)**
#
#
# **Question 9**
#
# 플라스크의 기본 포트인 5000번 포트로 접속했을 때 디자인이 깨질 경우 해결 방법은?
#
# ```
#
# (1) 컴퓨터를 재부팅한다.
# (2) 새로고침(F5)를 누른다.
# (3) 플라스크 내부의 웹 문서인 CSS 파일 및 JS 파일의 링크를 바르게 설정한다.
# (4) 포트 번호를 10000번으로 수정한다.
#
# ```
#
# **Answer : (3)**
#
#
# **Question 10**
#
# 서버 소스코드를 수정한 이후에는 다시 서버를 재구동할 때 혹시 ‘UTF-8’ 인코딩 관련 오류가 발생한다면 어떻게 해야 하는가?
#
# ```
#
# (1) 컴퓨터를 재부팅한다.
# (2) 새로고침(F5)를 누른다.
# (3) 서버 소스코드 파일을 ‘UTF-8’ 인코딩으로 저장한다..
# (4) 포트 번호를 10000번으로 수정한다.
#
# ```
#
# **Answer : (3)**
