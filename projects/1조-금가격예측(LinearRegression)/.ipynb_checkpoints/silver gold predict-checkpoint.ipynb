# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv
# 텐서플로우와 넘파이, 판다스를 불러옵니다.
# 텐서플로우는 머신러닝 라이브러리, 넘파이와 판다스는 데이터분석 라이브러리입니다.
# 판다스를 통해 read_csv기능을 불러와 저희가 정제한 csv파일을 읽습니다.

model = tf.global_variables_initializer();

data = read_csv('silver gold data.csv', sep=',')

xy = np.array(data, dtype=np.float32)

x_data = xy[:, 1:-1]
y_data = xy[:, [-1]]
# 저희 csv파일은 3열으로 x_data는 현재 2번째 열을 가져오며, y_data는 3번째 열을 가져오겠습니다.
W = tf.Variable(tf.random_uniform([1]), name="weight")
b = tf.Variable(tf.random_uniform([1]), name="bias")

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)
# X, Y 플레이스 홀더와 가중치와 바이어스를 설정합니다.
# 변인이 1개인 단순 선형 회귀이므로 값이 하나인 1차원 Array Shape을 가집니다.
hypothesis = W * X + b
# hypothesis = tf.matmul(X, W) + b로 표현하면 오류가 납니다.
# matmul은 변인이 2개 이상(또는 rank가 2이상)일 때 사용하는 것으로
# 단순선형회귀에서는 변인이 1개(또는 rank가 1)이기 때문에 y = Wx + b 형태로 만들어야 합니다.

cost = tf.reduce_mean(tf.square(hypothesis - Y))
# 비용 함수를 설정합니다.

rate = tf.Variable(0.0000005)
optimizer = tf.train.GradientDescentOptimizer(rate)
train = optimizer.minimize(cost)
# 이는 최적화 함수로, 학습률을 5 x 10^-7로 조정하고, 
# optimizer로 cost함수를 작게하겠다는 의미입니다.
# 텐서플로우에서 학습하면서 자동으로 W와 b값을 최소화합니다.
sess = tf.Session()
sess.run(tf.global_variables_initializer())
# 세션을 생성하고, 글로벌 변수를 초기화한 후에,
for step in range(100001):
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0:
        print("#", step, " 손실 비용: ", cost_)
        print("- 금 가격: ", hypo_[0])
        # 100001번의 학습을 수행하였습니다, 500steps 마다 step, 비용함수, 가설을 출력합니다.
# Out:
# # 0  손실 비용:  1545796.5
# - 금 가격:  [15.995435]
# # 500  손실 비용:  1226291.4
# - 금 가격:  [163.92365]
# # 1000  손실 비용:  972912.44
# - 금 가격:  [295.6574]
# # 1500  손실 비용:  771973.7
# - 금 가격:  [412.9699]
# # 2000  손실 비용:  612621.94
# - 금 가격:  [517.43976]
# # 2500  손실 비용:  486250.88
# - 금 가격:  [610.4724]
# # 3000  손실 비용:  386033.94
# - 금 가격:  [693.32056]
# # 3500  손실 비용:  306558.4
# - 금 가격:  [767.0989]
# # 4000  손실 비용:  243531.28
# - 금 가격:  [832.80054]
# # 4500  손실 비용:  193548.7
# - 금 가격:  [891.3094]
# # 5000  손실 비용:  153910.89
# - 금 가격:  [943.4128]
# # 5500  손실 비용:  122476.49
# - 금 가격:  [989.8125]
# # 6000  손실 비용:  97547.97
# - 금 가격:  [1031.1324]
# # 6500  손실 비용:  77778.87
# - 금 가격:  [1067.9288]
# # 7000  손실 비용:  62101.2
# - 금 가격:  [1100.6969]
# # 7500  손실 비용:  49668.246
# - 금 가격:  [1129.8778]
# # 8000  손실 비용:  39808.44
# - 금 가격:  [1155.8644]
# # 8500  손실 비용:  31989.291
# - 금 가격:  [1179.0059]
# # 9000  손실 비용:  25788.576
# - 금 가격:  [1199.6134]
# # 9500  손실 비용:  20871.08
# - 금 가격:  [1217.9653]
# # 10000  손실 비용:  16971.283
# - 금 가격:  [1234.3083]
# # 10500  손실 비용:  13878.691
# - 금 가격:  [1248.8619]
# # 11000  손실 비용:  11426.171
# - 금 가격:  [1261.822]
# # 11500  손실 비용:  9481.191
# - 금 가격:  [1273.3635]
# # 12000  손실 비용:  7938.7324
# - 금 가격:  [1283.6417]
# # 12500  손실 비용:  6715.4688
# - 금 가격:  [1292.795]
# # 13000  손실 비용:  5745.4146
# - 금 가격:  [1300.9459]
# # 13500  손실 비용:  4976.157
# - 금 가격:  [1308.2042]
# # 14000  손실 비용:  4366.0767
# - 금 가격:  [1314.6681]
# # 14500  손실 비용:  3882.2722
# - 금 가격:  [1320.4243]
# # 15000  손실 비용:  3498.5732
# - 금 가격:  [1325.5507]
# # 15500  손실 비용:  3194.338
# - 금 가격:  [1330.115]
# # 16000  손실 비용:  2952.9814
# - 금 가격:  [1334.1812]
# # 16500  손실 비용:  2761.6694
# - 금 가격:  [1337.8003]
# # 17000  손실 비용:  2609.905
# - 금 가격:  [1341.0243]
# # 17500  손실 비용:  2489.542
# - 금 가격:  [1343.8955]
# # 18000  손실 비용:  2394.1123
# - 금 가격:  [1346.4517]
# # 18500  손실 비용:  2318.422
# - 금 가격:  [1348.7284]
# # 19000  손실 비용:  2258.398
# - 금 가격:  [1350.7557]
# # 19500  손실 비용:  2210.801
# - 금 가격:  [1352.5609]
# # 20000  손실 비용:  2173.0554
# - 금 가격:  [1354.1683]
# # 20500  손실 비용:  2143.094
# - 금 가격:  [1355.6012]
# # 21000  손실 비용:  2119.3787
# - 금 가격:  [1356.8746]
# # 21500  손실 비용:  2100.5469
# - 금 가격:  [1358.01]
# # 22000  손실 비용:  2085.6184
# - 금 가격:  [1359.0206]
# # 22500  손실 비용:  2073.735
# - 금 가격:  [1359.924]
# # 23000  손실 비용:  2064.3828
# - 금 가격:  [1360.7223]
# # 23500  손실 비용:  2056.901
# - 금 가격:  [1361.4393]
# # 24000  손실 비용:  2050.9775
# - 금 가격:  [1362.077]
# # 24500  손실 비용:  2046.2997
# - 금 가격:  [1362.6423]
# # 25000  손실 비용:  2042.567
# - 금 가격:  [1363.1492]
# # 25500  손실 비용:  2039.653
# - 금 가격:  [1363.5931]
# # 26000  손실 비용:  2037.341
# - 금 가격:  [1363.988]
# # 26500  손실 비용:  2035.4685
# - 금 가격:  [1364.347]
# # 27000  손실 비용:  2033.9946
# - 금 가격:  [1364.6642]
# # 27500  손실 비용:  2032.8419
# - 금 가격:  [1364.9424]
# # 28000  손실 비용:  2031.9034
# - 금 가격:  [1365.1963]
# # 28500  손실 비용:  2031.166
# - 금 가격:  [1365.4205]
# # 29000  손실 비용:  2030.6051
# - 금 가격:  [1365.6111]
# # 29500  손실 비용:  2030.1057
# - 금 가격:  [1365.8018]
# # 30000  손실 비용:  2029.7504
# - 금 가격:  [1365.9541]
# # 30500  손실 비용:  2029.4833
# - 금 가격:  [1366.0814]
# # 31000  손실 비용:  2029.2433
# - 금 가격:  [1366.2087]
# # 31500  손실 비용:  2029.0312
# - 금 가격:  [1366.3359]
# # 32000  손실 비용:  2028.874
# - 금 가격:  [1366.443]
# # 32500  손실 비용:  2028.7871
# - 금 가격:  [1366.5072]
# # 33000  손실 비용:  2028.7086
# - 금 가격:  [1366.5712]
# # 33500  손실 비용:  2028.6364
# - 금 가격:  [1366.6353]
# # 34000  손실 비용:  2028.5715
# - 금 가격:  [1366.6992]
# # 34500  손실 비용:  2028.5131
# - 금 가격:  [1366.7633]
# # 35000  손실 비용:  2028.4619
# - 금 가격:  [1366.8273]
# # 35500  손실 비용:  2028.4185
# - 금 가격:  [1366.8912]
# # 36000  손실 비용:  2028.381
# - 금 가격:  [1366.9552]
# # 36500  손실 비용:  2028.3721
# - 금 가격:  [1366.9685]
# # 37000  손실 비용:  2028.3685
# - 금 가격:  [1366.9695]
# # 37500  손실 비용:  2028.3652
# - 금 가격:  [1366.9705]
# # 38000  손실 비용:  2028.3624
# - 금 가격:  [1366.9713]
# # 38500  손실 비용:  2028.359
# - 금 가격:  [1366.9723]
# # 39000  손실 비용:  2028.3558
# - 금 가격:  [1366.9733]
# # 39500  손실 비용:  2028.3523
# - 금 가격:  [1366.9742]
# # 40000  손실 비용:  2028.3491
# - 금 가격:  [1366.9752]
# # 40500  손실 비용:  2028.3456
# - 금 가격:  [1366.9762]
# # 41000  손실 비용:  2028.343
# - 금 가격:  [1366.977]
# # 41500  손실 비용:  2028.3395
# - 금 가격:  [1366.978]
# # 42000  손실 비용:  2028.3363
# - 금 가격:  [1366.979]
# # 42500  손실 비용:  2028.3329
# - 금 가격:  [1366.98]
# # 43000  손실 비용:  2028.3296
# - 금 가격:  [1366.981]
# # 43500  손실 비용:  2028.3265
# - 금 가격:  [1366.9818]
# # 44000  손실 비용:  2028.3232
# - 금 가격:  [1366.9828]
# # 44500  손실 비용:  2028.32
# - 금 가격:  [1366.9838]
# # 45000  손실 비용:  2028.3167
# - 금 가격:  [1366.9847]
# # 45500  손실 비용:  2028.3134
# - 금 가격:  [1366.9857]
# # 46000  손실 비용:  2028.3105
# - 금 가격:  [1366.9866]
# # 46500  손실 비용:  2028.307
# - 금 가격:  [1366.9875]
# # 47000  손실 비용:  2028.304
# - 금 가격:  [1366.9885]
# # 47500  손실 비용:  2028.3005
# - 금 가격:  [1366.9895]
# # 48000  손실 비용:  2028.2974
# - 금 가격:  [1366.9905]
# # 48500  손실 비용:  2028.294
# - 금 가격:  [1366.9915]
# # 49000  손실 비용:  2028.2913
# - 금 가격:  [1366.9923]
# # 49500  손실 비용:  2028.288
# - 금 가격:  [1366.9933]
# # 50000  손실 비용:  2028.2845
# - 금 가격:  [1366.9943]
# # 50500  손실 비용:  2028.2811
# - 금 가격:  [1366.9952]
# # 51000  손실 비용:  2028.278
# - 금 가격:  [1366.9962]
# # 51500  손실 비용:  2028.275
# - 금 가격:  [1366.9971]
# # 52000  손실 비용:  2028.2719
# - 금 가격:  [1366.998]
# # 52500  손실 비용:  2028.2687
# - 금 가격:  [1366.999]
# # 53000  손실 비용:  2028.2653
# - 금 가격:  [1367.]
# # 53500  손실 비용:  2028.262
# - 금 가격:  [1367.001]
# # 54000  손실 비용:  2028.2592
# - 금 가격:  [1367.0018]
# # 54500  손실 비용:  2028.256
# - 금 가격:  [1367.0028]
# # 55000  손실 비용:  2028.2526
# - 금 가격:  [1367.0038]
# # 55500  손실 비용:  2028.2491
# - 금 가격:  [1367.0048]
# # 56000  손실 비용:  2028.2461
# - 금 가격:  [1367.0057]
# # 56500  손실 비용:  2028.2426
# - 금 가격:  [1367.0067]
# # 57000  손실 비용:  2028.2397
# - 금 가격:  [1367.0076]
# # 57500  손실 비용:  2028.2366
# - 금 가격:  [1367.0085]
# # 58000  손실 비용:  2028.2334
# - 금 가격:  [1367.0095]
# # 58500  손실 비용:  2028.2308
# - 금 가격:  [1367.0103]
# # 59000  손실 비용:  2028.2285
# - 금 가격:  [1367.011]
# # 59500  손실 비용:  2028.2261
# - 금 가격:  [1367.0117]
# # 60000  손실 비용:  2028.2236
# - 금 가격:  [1367.0125]
# # 60500  손실 비용:  2028.2213
# - 금 가격:  [1367.0132]
# # 61000  손실 비용:  2028.2188
# - 금 가격:  [1367.0139]
# # 61500  손실 비용:  2028.2162
# - 금 가격:  [1367.0146]
# # 62000  손실 비용:  2028.214
# - 금 가격:  [1367.0154]
# # 62500  손실 비용:  2028.2118
# - 금 가격:  [1367.016]
# # 63000  손실 비용:  2028.2094
# - 금 가격:  [1367.0167]
# # 63500  손실 비용:  2028.207
# - 금 가격:  [1367.0175]
# # 64000  손실 비용:  2028.2046
# - 금 가격:  [1367.0182]
# # 64500  손실 비용:  2028.202
# - 금 가격:  [1367.0189]
# # 65000  손실 비용:  2028.1997
# - 금 가격:  [1367.0197]
# # 65500  손실 비용:  2028.1971
# - 금 가격:  [1367.0204]
# # 66000  손실 비용:  2028.1952
# - 금 가격:  [1367.021]
# # 66500  손실 비용:  2028.1926
# - 금 가격:  [1367.0217]
# # 67000  손실 비용:  2028.1903
# - 금 가격:  [1367.0225]
# # 67500  손실 비용:  2028.188
# - 금 가격:  [1367.0232]
# # 68000  손실 비용:  2028.1854
# - 금 가격:  [1367.0239]
# # 68500  손실 비용:  2028.1831
# - 금 가격:  [1367.0247]
# # 69000  손실 비용:  2028.1807
# - 금 가격:  [1367.0254]
# # 69500  손실 비용:  2028.1786
# - 금 가격:  [1367.026]
# # 70000  손실 비용:  2028.1761
# - 금 가격:  [1367.0267]
# # 70500  손실 비용:  2028.1737
# - 금 가격:  [1367.0275]
# # 71000  손실 비용:  2028.1713
# - 금 가격:  [1367.0282]
# # 71500  손실 비용:  2028.169
# - 금 가격:  [1367.0289]
# # 72000  손실 비용:  2028.1664
# - 금 가격:  [1367.0297]
# # 72500  손실 비용:  2028.1641
# - 금 가격:  [1367.0304]
# # 73000  손실 비용:  2028.1622
# - 금 가격:  [1367.031]
# # 73500  손실 비용:  2028.1595
# - 금 가격:  [1367.0317]
# # 74000  손실 비용:  2028.1572
# - 금 가격:  [1367.0325]
# # 74500  손실 비용:  2028.1549
# - 금 가격:  [1367.0332]
# # 75000  손실 비용:  2028.1523
# - 금 가격:  [1367.0339]
# # 75500  손실 비용:  2028.15
# - 금 가격:  [1367.0347]
# # 76000  손실 비용:  2028.1476
# - 금 가격:  [1367.0354]
# # 76500  손실 비용:  2028.1456
# - 금 가격:  [1367.036]
# # 77000  손실 비용:  2028.1433
# - 금 가격:  [1367.0367]
# # 77500  손실 비용:  2028.1409
# - 금 가격:  [1367.0375]
# # 78000  손실 비용:  2028.1384
# - 금 가격:  [1367.0382]
# # 78500  손실 비용:  2028.1361
# - 금 가격:  [1367.039]
# # 79000  손실 비용:  2028.1337
# - 금 가격:  [1367.0397]
# # 79500  손실 비용:  2028.1312
# - 금 가격:  [1367.0404]
# # 80000  손실 비용:  2028.1292
# - 금 가격:  [1367.041]
# # 80500  손실 비용:  2028.127
# - 금 가격:  [1367.0417]
# # 81000  손실 비용:  2028.1244
# - 금 가격:  [1367.0425]
# # 81500  손실 비용:  2028.1221
# - 금 가격:  [1367.0432]
# # 82000  손실 비용:  2028.1196
# - 금 가격:  [1367.044]
# # 82500  손실 비용:  2028.1172
# - 금 가격:  [1367.0447]
# # 83000  손실 비용:  2028.1147
# - 금 가격:  [1367.0454]
# # 83500  손실 비용:  2028.1129
# - 금 가격:  [1367.046]
# # 84000  손실 비용:  2028.1106
# - 금 가격:  [1367.0468]
# # 84500  손실 비용:  2028.1079
# - 금 가격:  [1367.0475]
# # 85000  손실 비용:  2028.1056
# - 금 가격:  [1367.0482]
# # 85500  손실 비용:  2028.1034
# - 금 가격:  [1367.049]
# # 86000  손실 비용:  2028.1007
# - 금 가격:  [1367.0497]
# # 86500  손실 비용:  2028.0985
# - 금 가격:  [1367.0504]
# # 87000  손실 비용:  2028.0964
# - 금 가격:  [1367.051]
# # 87500  손실 비용:  2028.0941
# - 금 가격:  [1367.0518]
# # 88000  손실 비용:  2028.0918
# - 금 가격:  [1367.0525]
# # 88500  손실 비용:  2028.0894
# - 금 가격:  [1367.0532]
# # 89000  손실 비용:  2028.087
# - 금 가격:  [1367.054]
# # 89500  손실 비용:  2028.0846
# - 금 가격:  [1367.0547]
# # 90000  손실 비용:  2028.0825
# - 금 가격:  [1367.0554]
# # 90500  손실 비용:  2028.0803
# - 금 가격:  [1367.056]
# # 91000  손실 비용:  2028.0779
# - 금 가격:  [1367.0568]
# # 91500  손실 비용:  2028.0756
# - 금 가격:  [1367.0575]
# # 92000  손실 비용:  2028.0731
# - 금 가격:  [1367.0582]
# # 92500  손실 비용:  2028.0709
# - 금 가격:  [1367.059]
# # 93000  손실 비용:  2028.0682
# - 금 가격:  [1367.0597]
# # 93500  손실 비용:  2028.0659
# - 금 가격:  [1367.0604]
# # 94000  손실 비용:  2028.0638
# - 금 가격:  [1367.061]
# # 94500  손실 비용:  2028.0618
# - 금 가격:  [1367.0618]
# # 95000  손실 비용:  2028.0593
# - 금 가격:  [1367.0625]
# # 95500  손실 비용:  2028.0569
# - 금 가격:  [1367.0632]
# # 96000  손실 비용:  2028.0547
# - 금 가격:  [1367.064]
# # 96500  손실 비용:  2028.0521
# - 금 가격:  [1367.0647]
# # 97000  손실 비용:  2028.0498
# - 금 가격:  [1367.0654]
# # 97500  손실 비용:  2028.0476
# - 금 가격:  [1367.0662]
# # 98000  손실 비용:  2028.0454
# - 금 가격:  [1367.0668]
# # 98500  손실 비용:  2028.0432
# - 금 가격:  [1367.0675]
# # 99000  손실 비용:  2028.0408
# - 금 가격:  [1367.0682]
# # 99500  손실 비용:  2028.0386
# - 금 가격:  [1367.069]
# # 100000  손실 비용:  2028.036
# - 금 가격:  [1367.0697]

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print('학습된 모델을 저장했습니다.')
# 학습된 모델을 저장했습니다.
# Out:
# 학습된 모델을 저장했습니다.

# %%
# %%writefile plot_hour2grade.py

import matplotlib.pyplot as plt  
%matplotlib inline
# 그리고 그래프를 출력하기 위해 맷플랏라이브러리를 불러왔습니다.
# Out:
# Overwriting plot_hour2grade.py

# %%
mx = np.mean(x_data)
my = np.mean(y_data)
print("x의 평균값:", mx)
print("y의 평균값:", my)
# x_data와 y_data로부터 값을 불러와

divisor = sum([(mx - i)**2 for i in x_data])
# 기울기 공식의 분모를 정하고

def top(x_data, mx, y_data, my):
    d = 0
    for i in range(len(x_data)):
        d += (x_data[i] - mx) * (y_data[i] - my)
    return d
dividend = top(x_data, mx, y_data, my)
# 기울기 공식의 분자를 정합니다.
print("분모:", divisor)
print("분자:", dividend)

a = dividend / divisor
b = my - (mx*a)
# 기울기와 y 절편을 구하고

print("기울기 a =", a)
print("y 절편 b =", b)

xline = np.arange(12, 18, 0.1)
yline = a * xline + b
# 은과 금 가격의 그래프에서 범위를 적절히 조정하였습니다.
# Out:
# x의 평균값: 15.1776285
# y의 평균값: 1257.3325
# 분모: [127.06607]
# 분자: [4856.692]
# 기울기 a = [38.221783]
# y 절편 b = [677.2165]

# %%
plt.figure()  
plt.plot(x_data, y_data, 'ob')  
plt.plot(xline, yline)
plt.title('Silver to Gold')
plt.xlabel('Silver price')
plt.ylabel('Gold price')
plt.show()
# 보시면 은과 금 가격의 규칙성 있는 분포도를 확인할 수 있으며
# 수요와 공급의 원리에 따라 이루어진 상관관계로부터 선형회귀를 확인할 수 있겠습니다.
# plt가 지정되지 않았다는 오류가 뜬다면 'import matplotlib.pyplot as plt'를 맨 앞 줄에 작성하여 실행 후
# 다시 제거하여 실행하면 오류가 해결됩니다. 이와 같은 경우에 변수를 def하여 plt를 한꺼번에 작동시키는 편이나 이것 또한 오류가 발생하여
# plt를 직접 사용하였습니다.
