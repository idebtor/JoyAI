# %% [markdown]
# # LectureNote: Project - 1
#
#
# # Project - 선형회귀를 활용한 배추가격 예측 AI 개발 (1 ~ 7강)

# %% [markdown]
# ### 추천의 말
# 여기에 소개하는 "안경잡이 개발자(동빈나)" 강의는 최근(2018)에 만들어지고, 우리의 교육과정의 일부분으로 적합하여 여러분에게 수강을 추천합니다. 모든 동영상 강의가 유튜브에 공개되어 있을 뿐만 아니라 [naver blog](https://blog.naver.com/ndb796/221036493985)에는 스크립트와 함께 동영상을 볼 수 있습니다.
#
# 본 프로젝트도 동빈나 강의자가 유튜브에 1강부터 7강까지로 소개하고 있습니다. 아래와 같이 자료들과 깃허브 소스도 제공하고 있으니 참고하길 바랍니다.
#
# - [블로그와 자료](https://ndb796.tistory.com/124?category=1013932)
#
# - [깃허브 자료와 소스](https://github.com/ndb796/Vegita/blob/master/README.md)
#
# - [웹서버 부트스트랩](https://mdbootstrap.com/freebies/jquery/full-page-video-carousel/)
#
# #### 1. [프로젝트 개요](https://www.youtube.com/watch?v=wZvhBVqitn8&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=13) (4:30)
#
# #### 2. [프로젝트 아이디어 결정 및 데이터 수집](https://www.youtube.com/watch?v=86u8TmkRN38&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=14) (4:46)
#
# #### 3. [다변인 선형회귀 모델 개발하기](https://www.youtube.com/watch?v=9Ur7bbZtoTc&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=15) (8:44)
#
# #### 4. [저장된 학습 모델로 배추 가격 예측하기](https://www.youtube.com/watch?v=xJuW_DltmDE&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=16) (4:09)
#
# #### 5. [기초 데이터 시각화하기](https://www.youtube.com/watch?v=EtW6c8W_cnw&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=17) (3:32)
#
# #### 6. [플라스크 웹 서버와 웹 디자인](https://www.youtube.com/watch?v=gmbkKE-jUUE&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=18) (6:21)
#
# #### 7. [플라스크와 텐서플로우 연동하기](https://www.youtube.com/watch?v=gmbkKE-jUUE&list=PLRx0vPvlEmdAbnmLH9yh03cw9UQU_o7PO&index=18) (5:44)

# %% [markdown]
# ## Anaconda를 설치한 후, Tensorflow 설치하기

# %% [markdown]
# 관리자 권한으로 Windows cmd 혹은 powershell을 시작합니다. Mac에서는 terminal을 시작합니다.
#
# 1. 다음 명령어로 파이썬 버전을 확인합니다.
#
# ```
#    python --version
#
#    (Python 3.7.1 출력된다면, Python 3.7 버전입니다)
# ```
#
#
# 2. pip를 upgrade합니다.
#
# ```
#     python -m pip install --upgrade pip
# ```
#
# 3. conda를 이용하여 tensorflow라는 가상환경(virtual environment)를 만듭니다.
#
# ```
#     conda create -n tensorflow python=3.7
# ```
#
# 4. 위에서 만든 tensorflow 가상환경을 활성화합니다.
#
# ```
#     activate tensorflow
# ```
#
# 5. 활성화된 tensorflow 가상환경에 tensorflow를 설치합니다.
#
# ```
#     pip install tensorflow
# ```
#
# 6. 이제 콘솔 창에서 tensorflow 설치를 확인합니다. Python을 시작하여, tensorflow를 import 하고, 버전을 확인하면 됩니다.
#
# ```
#    python
#    import tensorflow as tf
#    print(tf.__version__)
#    exit()
# ```
#
# 참고로, keras도 pip를 이용하여 다음과 같이 설치할 수 있습니다.
#
#     pip install keras

# %%
import tensorflow as tf
import numpy as np
from pandas.io.parsers import read_csv

model = tf.global_variables_initializer()

data = read_csv('price data.csv', sep=',')

xy = np.array(data, dtype=np.float32)

# %%
x_data = xy[:, 1:-1]
y_data = xy[:, [-1]]

# %%
X = tf.placeholder(tf.float32, shape=[None, 4])
Y = tf.placeholder(tf.float32, shape=[None, 1])
W = tf.Variable(tf.random_normal([4, 1]), name="weight")
b = tf.Variable(tf.random_normal([1]), name="bias")
# Out:
# WARNING:tensorflow:From C:\Users\kjb13\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
hypothesis = tf.matmul(X, W) + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.000005)
train = optimizer.minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
for step in range(100001) :
    cost_, hypo_, _ = sess.run([cost, hypothesis, train], feed_dict={X: x_data, Y: y_data})
    if step % 500 == 0 :
        print("#", step, "손실 비용:", cost_)
        print("- 배추 가격: ", hypo_[0])
# Out:
# # 0 손실 비용: 12382456.0
# - 배추 가격:  [12.020517]
# # 500 손실 비용: 4171361.8
# - 배추 가격:  [-259.93964]
# # 1000 손실 비용: 3769502.8
# - 배추 가격:  [48.195538]
# # 1500 손실 비용: 3455705.8
# - 배추 가격:  [328.86392]
# # 2000 손실 비용: 3208943.0
# - 배추 가격:  [578.22003]
# # 2500 손실 비용: 3014415.0
# - 배추 가격:  [799.7529]
# # 3000 손실 비용: 2860813.2
# - 배추 가격:  [996.6209]
# # 3500 손실 비용: 2739397.5
# - 배추 가격:  [1171.6097]
# # 4000 손실 비용: 2643349.8
# - 배추 가격:  [1327.1781]
# # 4500 손실 비용: 2567328.2
# - 배추 가격:  [1465.5012]
# # 5000 손실 비용: 2507129.0
# - 배추 가격:  [1588.5049]
# # 5500 손실 비용: 2459438.5
# - 배추 가격:  [1697.8959]
# # 6000 손실 비용: 2421641.8
# - 배추 가격:  [1795.1892]
# # 6500 손실 비용: 2391671.5
# - 배추 가격:  [1881.7261]
# # 7000 손실 비용: 2367894.8
# - 배추 가격:  [1958.7008]
# # 7500 손실 비용: 2349017.8
# - 배추 가격:  [2027.1727]
# # 8000 손실 비용: 2334018.2
# - 배추 가격:  [2088.082]
# # 8500 손실 비용: 2322087.5
# - 배추 가격:  [2142.266]
# # 9000 손실 비용: 2312586.0
# - 배추 가격:  [2190.469]
# # 9500 손실 비용: 2305006.2
# - 배추 가격:  [2233.3513]
# # 10000 손실 비용: 2298948.2
# - 배추 가격:  [2271.502]
# # 10500 손실 비용: 2294093.0
# - 배추 가격:  [2305.4436]
# # 11000 손실 비용: 2290191.0
# - 배추 가격:  [2335.6406]
# # 11500 손실 비용: 2287043.8
# - 배추 가격:  [2362.5066]
# # 12000 손실 비용: 2284493.5
# - 배추 가격:  [2386.4092]
# # 12500 손실 비용: 2282415.0
# - 배추 가격:  [2407.6772]
# # 13000 손실 비용: 2280711.0
# - 배추 가격:  [2426.5999]
# # 13500 손실 비용: 2279302.5
# - 배추 가격:  [2443.4358]
# # 14000 손실 비용: 2278129.0
# - 배추 가격:  [2458.4167]
# # 14500 손실 비용: 2277140.8
# - 배추 가격:  [2471.7473]
# # 15000 손실 비용: 2276298.5
# - 배추 가격:  [2483.6094]
# # 15500 손실 비용: 2275573.5
# - 배추 가격:  [2494.1643]
# # 16000 손실 비용: 2274940.5
# - 배추 가격:  [2503.557]
# # 16500 손실 비용: 2274379.8
# - 배추 가격:  [2511.9158]
# # 17000 손실 비용: 2273877.2
# - 배추 가격:  [2519.3547]
# # 17500 손실 비용: 2273420.2
# - 배추 가격:  [2525.975]
# # 18000 손실 비용: 2272999.8
# - 배추 가격:  [2531.8682]
# # 18500 손실 비용: 2272607.2
# - 배추 가격:  [2537.1135]
# # 19000 손실 비용: 2272238.2
# - 배추 가격:  [2541.7817]
# # 19500 손실 비용: 2271887.2
# - 배추 가격:  [2545.9377]
# # 20000 손실 비용: 2271550.5
# - 배추 가격:  [2549.6401]
# # 20500 손실 비용: 2271224.8
# - 배추 가격:  [2552.9346]
# # 21000 손실 비용: 2270908.8
# - 배추 가격:  [2555.8662]
# # 21500 손실 비용: 2270599.0
# - 배추 가격:  [2558.4785]
# # 22000 손실 비용: 2270296.5
# - 배추 가격:  [2560.804]
# # 22500 손실 비용: 2269996.8
# - 배추 가격:  [2562.8762]
# # 23000 손실 비용: 2269702.5
# - 배추 가격:  [2564.7253]
# # 23500 손실 비용: 2269409.8
# - 배추 가격:  [2566.369]
# # 24000 손실 비용: 2269120.2
# - 배추 가격:  [2567.832]
# # 24500 손실 비용: 2268831.8
# - 배추 가격:  [2569.1353]
# # 25000 손실 비용: 2268545.8
# - 배추 가격:  [2570.3035]
# # 25500 손실 비용: 2268261.0
# - 배추 가격:  [2571.3425]
# # 26000 손실 비용: 2267976.5
# - 배추 가격:  [2572.2708]
# # 26500 손실 비용: 2267693.8
# - 배추 가격:  [2573.0989]
# # 27000 손실 비용: 2267411.5
# - 배추 가격:  [2573.8342]
# # 27500 손실 비용: 2267129.2
# - 배추 가격:  [2574.4827]
# # 28000 손실 비용: 2266848.0
# - 배추 가격:  [2575.0798]
# # 28500 손실 비용: 2266567.8
# - 배추 가격:  [2575.6067]
# # 29000 손실 비용: 2266287.5
# - 배추 가격:  [2576.0935]
# # 29500 손실 비용: 2266007.5
# - 배추 가격:  [2576.516]
# # 30000 손실 비용: 2265727.5
# - 배추 가격:  [2576.9023]
# # 30500 손실 비용: 2265448.2
# - 배추 가격:  [2577.2358]
# # 31000 손실 비용: 2265169.8
# - 배추 가격:  [2577.5557]
# # 31500 손실 비용: 2264891.2
# - 배추 가격:  [2577.806]
# # 32000 손실 비용: 2264612.5
# - 배추 가격:  [2578.046]
# # 32500 손실 비용: 2264333.8
# - 배추 가격:  [2578.2822]
# # 33000 손실 비용: 2264055.5
# - 배추 가격:  [2578.509]
# # 33500 손실 비용: 2263777.8
# - 배추 가격:  [2578.7007]
# # 34000 손실 비용: 2263499.8
# - 배추 가격:  [2578.8318]
# # 34500 손실 비용: 2263222.5
# - 배추 가격:  [2578.9604]
# # 35000 손실 비용: 2262945.5
# - 배추 가격:  [2579.088]
# # 35500 손실 비용: 2262669.0
# - 배추 가격:  [2579.2156]
# # 36000 손실 비용: 2262392.5
# - 배추 가격:  [2579.3433]
# # 36500 손실 비용: 2262115.2
# - 배추 가격:  [2579.471]
# # 37000 손실 비용: 2261838.8
# - 배추 가격:  [2579.5955]
# # 37500 손실 비용: 2261563.0
# - 배추 가격:  [2579.7156]
# # 38000 손실 비용: 2261287.2
# - 배추 가격:  [2579.8303]
# # 38500 손실 비용: 2261011.5
# - 배추 가격:  [2579.911]
# # 39000 손실 비용: 2260735.2
# - 배추 가격:  [2579.9485]
# # 39500 손실 비용: 2260459.2
# - 배추 가격:  [2579.9863]
# # 40000 손실 비용: 2260185.2
# - 배추 가격:  [2580.0234]
# # 40500 손실 비용: 2259909.8
# - 배추 가격:  [2580.059]
# # 41000 손실 비용: 2259635.5
# - 배추 가격:  [2580.0918]
# # 41500 손실 비용: 2259361.5
# - 배추 가격:  [2580.1255]
# # 42000 손실 비용: 2259087.8
# - 배추 가격:  [2580.1592]
# # 42500 손실 비용: 2258813.5
# - 배추 가격:  [2580.1926]
# # 43000 손실 비용: 2258539.5
# - 배추 가격:  [2580.2266]
# # 43500 손실 비용: 2258265.8
# - 배추 가격:  [2580.2598]
# # 44000 손실 비용: 2257992.8
# - 배추 가격:  [2580.293]
# # 44500 손실 비용: 2257719.0
# - 배추 가격:  [2580.3284]
# # 45000 손실 비용: 2257446.2
# - 배추 가격:  [2580.3643]
# # 45500 손실 비용: 2257173.0
# - 배추 가격:  [2580.402]
# # 46000 손실 비용: 2256899.8
# - 배추 가격:  [2580.442]
# # 46500 손실 비용: 2256626.8
# - 배추 가격:  [2580.482]
# # 47000 손실 비용: 2256354.5
# - 배추 가격:  [2580.5254]
# # 47500 손실 비용: 2256082.0
# - 배추 가격:  [2580.5664]
# # 48000 손실 비용: 2255810.8
# - 배추 가격:  [2580.605]
# # 48500 손실 비용: 2255539.8
# - 배추 가격:  [2580.647]
# # 49000 손실 비용: 2255268.8
# - 배추 가격:  [2580.6892]
# # 49500 손실 비용: 2254998.2
# - 배추 가격:  [2580.732]
# # 50000 손실 비용: 2254727.2
# - 배추 가격:  [2580.7776]
# # 50500 손실 비용: 2254456.0
# - 배추 가격:  [2580.8242]
# # 51000 손실 비용: 2254185.8
# - 배추 가격:  [2580.8699]
# # 51500 손실 비용: 2253915.2
# - 배추 가격:  [2580.9163]
# # 52000 손실 비용: 2253645.2
# - 배추 가격:  [2580.9658]
# # 52500 손실 비용: 2253375.0
# - 배추 가격:  [2581.0154]
# # 53000 손실 비용: 2253105.0
# - 배추 가격:  [2581.0627]
# # 53500 손실 비용: 2252835.0
# - 배추 가격:  [2581.1165]
# # 54000 손실 비용: 2252565.2
# - 배추 가격:  [2581.1704]
# # 54500 손실 비용: 2252296.0
# - 배추 가격:  [2581.223]
# # 55000 손실 비용: 2252027.8
# - 배추 가격:  [2581.2712]
# # 55500 손실 비용: 2251758.8
# - 배추 가격:  [2581.3196]
# # 56000 손실 비용: 2251490.5
# - 배추 가격:  [2581.3674]
# # 56500 손실 비용: 2251222.2
# - 배추 가격:  [2581.4158]
# # 57000 손실 비용: 2250954.5
# - 배추 가격:  [2581.464]
# # 57500 손실 비용: 2250686.0
# - 배추 가격:  [2581.5125]
# # 58000 손실 비용: 2250418.0
# - 배추 가격:  [2581.5605]
# # 58500 손실 비용: 2250150.8
# - 배추 가격:  [2581.6086]
# # 59000 손실 비용: 2249883.5
# - 배추 가격:  [2581.656]
# # 59500 손실 비용: 2249616.8
# - 배추 가격:  [2581.703]
# # 60000 손실 비용: 2249350.5
# - 배추 가격:  [2581.7532]
# # 60500 손실 비용: 2249085.0
# - 배추 가격:  [2581.8037]
# # 61000 손실 비용: 2248818.5
# - 배추 가격:  [2581.854]
# # 61500 손실 비용: 2248553.0
# - 배추 가격:  [2581.9045]
# # 62000 손실 비용: 2248287.2
# - 배추 가격:  [2581.9548]
# # 62500 손실 비용: 2248021.8
# - 배추 가격:  [2582.0051]
# # 63000 손실 비용: 2247755.5
# - 배추 가격:  [2582.0479]
# # 63500 손실 비용: 2247489.5
# - 배추 가격:  [2582.0815]
# # 64000 손실 비용: 2247224.2
# - 배추 가격:  [2582.1143]
# # 64500 손실 비용: 2246959.5
# - 배추 가격:  [2582.1482]
# # 65000 손실 비용: 2246694.2
# - 배추 가격:  [2582.1812]
# # 65500 손실 비용: 2246429.0
# - 배추 가격:  [2582.2148]
# # 66000 손실 비용: 2246164.5
# - 배추 가격:  [2582.2485]
# # 66500 손실 비용: 2245899.5
# - 배추 가격:  [2582.2822]
# # 67000 손실 비용: 2245634.8
# - 배추 가격:  [2582.3162]
# # 67500 손실 비용: 2245370.2
# - 배추 가격:  [2582.3499]
# # 68000 손실 비용: 2245106.0
# - 배추 가격:  [2582.3833]
# # 68500 손실 비용: 2244841.5
# - 배추 가격:  [2582.4175]
# # 69000 손실 비용: 2244577.2
# - 배추 가격:  [2582.4514]
# # 69500 손실 비용: 2244313.5
# - 배추 가격:  [2582.4854]
# # 70000 손실 비용: 2244049.5
# - 배추 가격:  [2582.519]
# # 70500 손실 비용: 2243785.8
# - 배추 가격:  [2582.5532]
# # 71000 손실 비용: 2243522.2
# - 배추 가격:  [2582.5874]
# # 71500 손실 비용: 2243258.8
# - 배추 가격:  [2582.621]
# # 72000 손실 비용: 2242995.0
# - 배추 가격:  [2582.6506]
# # 72500 손실 비용: 2242732.0
# - 배추 가격:  [2582.6802]
# # 73000 손실 비용: 2242468.2
# - 배추 가격:  [2582.7092]
# # 73500 손실 비용: 2242206.8
# - 배추 가격:  [2582.735]
# # 74000 손실 비용: 2241946.5
# - 배추 가격:  [2582.7542]
# # 74500 손실 비용: 2241685.8
# - 배추 가격:  [2582.7712]
# # 75000 손실 비용: 2241425.0
# - 배추 가격:  [2582.7878]
# # 75500 손실 비용: 2241165.2
# - 배추 가격:  [2582.8047]
# # 76000 손실 비용: 2240904.2
# - 배추 가격:  [2582.8213]
# # 76500 손실 비용: 2240645.2
# - 배추 가격:  [2582.8381]
# # 77000 손실 비용: 2240385.0
# - 배추 가격:  [2582.855]
# # 77500 손실 비용: 2240124.5
# - 배추 가격:  [2582.8699]
# # 78000 손실 비용: 2239865.0
# - 배추 가격:  [2582.8809]
# # 78500 손실 비용: 2239605.8
# - 배추 가격:  [2582.8926]
# # 79000 손실 비용: 2239345.8
# - 배추 가격:  [2582.904]
# # 79500 손실 비용: 2239086.2
# - 배추 가격:  [2582.9155]
# # 80000 손실 비용: 2238827.0
# - 배추 가격:  [2582.9268]
# # 80500 손실 비용: 2238568.0
# - 배추 가격:  [2582.9382]
# # 81000 손실 비용: 2238308.5
# - 배추 가격:  [2582.9497]
# # 81500 손실 비용: 2238049.2
# - 배추 가격:  [2582.9612]
# # 82000 손실 비용: 2237790.8
# - 배추 가격:  [2582.9727]
# # 82500 손실 비용: 2237532.0
# - 배추 가격:  [2582.981]
# # 83000 손실 비용: 2237273.2
# - 배추 가격:  [2582.987]
# # 83500 손실 비용: 2237014.8
# - 배추 가격:  [2582.9932]
# # 84000 손실 비용: 2236756.8
# - 배추 가격:  [2582.9993]
# # 84500 손실 비용: 2236497.8
# - 배추 가격:  [2583.0054]
# # 85000 손실 비용: 2236238.8
# - 배추 가격:  [2583.0117]
# # 85500 손실 비용: 2235980.8
# - 배추 가격:  [2583.0178]
# # 86000 손실 비용: 2235723.0
# - 배추 가격:  [2583.0305]
# # 86500 손실 비용: 2235464.2
# - 배추 가격:  [2583.065]
# # 87000 손실 비용: 2235207.5
# - 배추 가격:  [2583.0994]
# # 87500 손실 비용: 2234949.0
# - 배추 가격:  [2583.1335]
# # 88000 손실 비용: 2234691.2
# - 배추 가격:  [2583.1677]
# # 88500 손실 비용: 2234434.5
# - 배추 가격:  [2583.2024]
# # 89000 손실 비용: 2234177.5
# - 배추 가격:  [2583.237]
# # 89500 손실 비용: 2233920.5
# - 배추 가격:  [2583.2717]
# # 90000 손실 비용: 2233663.0
# - 배추 가격:  [2583.3054]
# # 90500 손실 비용: 2233405.8
# - 배추 가격:  [2583.3403]
# # 91000 손실 비용: 2233152.0
# - 배추 가격:  [2583.3748]
# # 91500 손실 비용: 2232897.8
# - 배추 가격:  [2583.4084]
# # 92000 손실 비용: 2232643.8
# - 배추 가격:  [2583.443]
# # 92500 손실 비용: 2232389.5
# - 배추 가격:  [2583.477]
# # 93000 손실 비용: 2232135.5
# - 배추 가격:  [2583.511]
# # 93500 손실 비용: 2231881.5
# - 배추 가격:  [2583.5447]
# # 94000 손실 비용: 2231627.8
# - 배추 가격:  [2583.5786]
# # 94500 손실 비용: 2231374.2
# - 배추 가격:  [2583.6135]
# # 95000 손실 비용: 2231120.8
# - 배추 가격:  [2583.6475]
# # 95500 손실 비용: 2230867.0
# - 배추 가격:  [2583.6826]
# # 96000 손실 비용: 2230614.0
# - 배추 가격:  [2583.717]
# # 96500 손실 비용: 2230360.8
# - 배추 가격:  [2583.7515]
# # 97000 손실 비용: 2230107.8
# - 배추 가격:  [2583.7856]
# # 97500 손실 비용: 2229854.5
# - 배추 가격:  [2583.8208]
# # 98000 손실 비용: 2229602.0
# - 배추 가격:  [2583.855]
# # 98500 손실 비용: 2229349.0
# - 배추 가격:  [2583.8901]
# # 99000 손실 비용: 2229097.2
# - 배추 가격:  [2583.9253]
# # 99500 손실 비용: 2228844.8
# - 배추 가격:  [2583.9602]
# # 100000 손실 비용: 2228592.8
# - 배추 가격:  [2583.995]

# %%
saver = tf.train.Saver()
save_path = saver.save(sess, "./saved.cpkt")
print("학습된 모델을 저장했습니다.")
# Out:
# 학습된 모델을 저장했습니다.

# %%
print(xy)
# Out:
# [[ 2.0100100e+07 -4.9000001e+00 -1.1000000e+01  8.9999998e-01
#    0.0000000e+00  2.1230000e+03]
#  [ 2.0100102e+07 -3.0999999e+00 -5.5000000e+00  5.5000000e+00
#    8.0000001e-01  2.1230000e+03]
#  [ 2.0100104e+07 -2.9000001e+00 -6.9000001e+00  1.4000000e+00
#    0.0000000e+00  2.1230000e+03]
#  ...
#  [ 2.0171228e+07  2.9000001e+00 -2.0999999e+00  8.0000000e+00
#    0.0000000e+00  2.9010000e+03]
#  [ 2.0171230e+07  2.9000001e+00 -1.6000000e+00  7.0999999e+00
#    6.0000002e-01  2.9010000e+03]
#  [ 2.0171232e+07  2.0999999e+00 -2.0000000e+00  5.8000002e+00
#    4.0000001e-01  2.9010000e+03]]
