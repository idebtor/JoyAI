# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pandas as pd
from pandas import DataFrame
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import feature_column
from tensorflow.keras import layers
import pathlib
from tensorflow import keras
import os
from keras.callbacks import ModelCheckpoint
from sklearn import datasets, metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
import xgboost as xgb
from sklearn import datasets
from sklearn.datasets import dump_svmlight_file
from sklearn.externals import joblib
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
import csv
from keras.layers import Input, Dense    #using set model component
from keras.models import Model    #using set model 
from keras.utils import plot_model    #show model structure
from keras import layers as Layer
import keras 
from pandas import DataFrame as df
from keras.callbacks import EarlyStopping
import gzip
import pickle
from keras import backend as K
import tensorflow as tf
from keras.layers import Dense, Dropout, Input, Activation, BatchNormalization
# Out:
# Using TensorFlow backend.
# /home/eunchoding/anaconda3/envs/tensorflow115/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
def check_correct(predict, y):
    result = {}
    result['True-Positive'] = 0
    result['True-Negative'] = 0
    result['False-Negative'] = 0
    result['False-Positive'] = 0

    for i in range(len(predict)) :
        if predict[i] == y[i] :
            if y[i] == 0 :
                result['True-Negative'] += 1
            else :
                result['True-Positive'] += 1
        else :
            if y[i] == 0 :
                result['False-Positive'] += 1
            else :
                result['False-Negative'] += 1

    for result_k, result_v in result.items():
        print(result_k +" : "+ str(result_v))
    
    acc=(result['True-Positive']+result['True-Negative'])/len(y)
    sensitivity=result['True-Positive']/(result['True-Positive']+result['False-Negative'])
    specificity=result['True-Negative']/(result['True-Negative']+result['False-Positive'])
    print("Accuracy :", acc)
    print("Sensitivity :", sensitivity)
    print("Specificity :", specificity)
    return acc, sensitivity, specificity

# %%
def model_performance(x, model, y):
    hypo = model.predict_proba(x)
    pred = np.where(df(hypo)[1] > 0.5, 1, 0).flatten()
    acc, sen, spe=check_correct(pred, y)
    auc=metrics.roc_auc_score(y, df(hypo)[1])
    
    
    df_hypo=df(hypo)[1]
    df_hypo.columns=['hypothesis 1']
    
    df_pred=df(pred)
    df_pred.columns=['prediction']
    
    df_y=df(y)
    df_y.columns=['y']
    
    pred_result=pd.concat([df_y,df_hypo, df_pred],axis=1)
    
    print("Accuracy : ",acc)
    print("AUC : ",auc)
    print(" ")
    print(df(pd.crosstab(y, pred, rownames=['Actual'], colnames=['Predicted'], margins=True)))
    print(" ")
    print(df(pred_result))

    return acc ,sen, spe ,auc, pred_result

# %%
def model_performance_DNN(x, model, y):
    hypo = model.predict(x)
    pred = np.where(hypo > 0.5, 1, 0).flatten()
    acc, sen, spe=check_correct(pred, y)
    auc=metrics.roc_auc_score(y, hypo)
    
    df_hypo=df(hypo)
    df_hypo.columns=['hypothesis 1']
    
    df_pred=df(pred)
    df_pred.columns=['prediction']
    
    df_y=df(y)
    df_y.columns=['y']
    
    pred_result=pd.concat([df_y,df_hypo, df_pred],axis=1)
    
    print("Accuracy : ",acc)
    print("AUC : ",auc)
    print(" ")
    print(df(pd.crosstab(y, pred, rownames=['Actual'], colnames=['Predicted'], margins=True)))
    print(" ")
    print(df(pred_result))

    return acc ,sen, spe ,auc, pred_result

# %% [markdown]
# ### Ensemble Model
# ##### Classification 1

# %%
dataframe = pd.read_csv("./IRIS_train_data_feature16.csv")
dataframe
# Out:
#          SampleID      APOE    CR     EOTAXIN       FASL  genus_Coprococcus  \
# 0      ZJTKAE3.02  5.143022  0.80   92.908626  18.942427           0.004463
# 1      ZJTKAE3.04  5.141314  0.80   78.127709  17.828167           0.008623
# 2      ZJTKAE3.06  4.997737  0.90  108.745324  21.170948           0.004238
# 3    ZJTKAE3.2012  5.385313  1.00   66.514130  20.056687           0.001555
# 4    ZJTKAE3.2013  5.172769  1.20   87.101837  21.170948           0.000975
# ..            ...       ...   ...         ...        ...                ...
# 338    ZYXQKWY.05  4.692352  0.80  105.632147  28.146719           0.001885
# 339    ZYXQKWY.06  4.223759  0.70  114.622117  26.867323           0.002520
# 340    ZYXQKWY.07  4.874428  0.56  101.137162  27.507021           0.003061
# 341    ZYXQKWY.08  4.851328  0.64   85.404714  26.867323           0.001406
# 342    ZYXQKWY.09  4.780157  0.57  119.117101  29.426115           0.005665
#
#           GMCSF  HDL      IGHM       IL7.x        LEPTIN        MCP1   MCV  \
# 0     81.497581   78  4.848248   19.782682   8167.369050  567.725245  86.5
# 1     56.095737   82  4.777619   24.178833   6258.660698  486.041809  85.5
# 2     63.504608   72  4.741192   23.079795   6077.686060  530.688656  86.3
# 3     50.803687   84  5.228373   24.178833   6276.703487  471.328644  87.2
# 4     49.745276   81  4.816603   25.277871   5335.197964  475.894799  87.0
# ..          ...  ...       ...         ...           ...         ...   ...
# 338   71.477287   67  5.430463   70.228793   8320.895338  996.713659  93.8
# 339   83.848356   54  5.507870  104.089104   8380.560673  737.738486  91.6
# 340  103.779523   64  5.271156   90.294163   9298.116767  759.887678  92.9
# 341  107.215931   62  5.252873   51.417509  10606.453930  751.368758  92.8
# 342  106.528649   70  5.128759   68.347665  10520.449840  937.081218  91.1
#
#      MONOAB        SCF   SSPG  SSPG_classification  TGL       LPA  index
# 0      0.47  50.177236  162.0                    1   61 -1.489310      1
# 1      0.43  36.298426  162.0                    1   56 -1.187511      2
# 2      0.52  43.771632  162.0                    1  103 -3.774880      3
# 3      0.43  38.433628  162.0                    1   96 -1.370451      2
# 4      0.53  46.974434  162.0                    1   85 -1.838588      2
# ..      ...        ...    ...                  ...  ...       ...    ...
# 338    0.64  67.598360  158.5                    1  130 -0.942503      4
# 339    0.39  53.849541  158.5                    1   83 -1.618222      3
# 340    0.67  63.588288  158.5                    1   91 -2.152476      2
# 341    0.78  93.950264  158.5                    1  150  0.156366      4
# 342    0.54  99.678938  158.5                    1  118 -1.457898      5
#
# [343 rows x 20 columns]

# %%
value= dataframe.drop(["SampleID", "SSPG_classification","SSPG", "index"],axis=1)
interest = dataframe.SSPG_classification

print("Information of Training Data")
print("Samples : {}".format(value.shape[0]))
print("Features : {}".format(value.shape[1]))
# Out:
# Information of Training Data
# Samples : 343
# Features : 16

# %%
#MinMax
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd

X = np.array(value)
min_max_scaler = MinMaxScaler()
X_MinMax = min_max_scaler.fit_transform(X)

# %%
#X_MinMax = df(X_MinMax)
#X_MinMax.to_csv("./minmax.csv")

# %%
train_x, test_x, train_y, test_y = train_test_split(X_MinMax, interest, test_size=0.2, random_state=11,stratify=interest)

# %%
rfc = RandomForestClassifier(n_estimators=150, max_depth=5, min_samples_split=2)
abc = AdaBoostClassifier(n_estimators=350, learning_rate=0.05)
gbc = GradientBoostingClassifier(n_estimators=400, learning_rate=0.01, min_samples_split=2)
xgb_clf = xgb.XGBClassifier(n_estimators=250, max_depth=5,learning_rate=0.05)

# %%
rfc.fit(train_x, train_y)
abc.fit(train_x, train_y)
gbc.fit(train_x, train_y)
xgb_clf.fit(train_x, train_y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.05, max_delta_step=0, max_depth=5,
#               min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# Random forest
y_pred_rfc = rfc.predict_proba(test_x)[:,1]
fpr_rfc, tpr_rfc, thresholds_rfc = roc_curve(test_y, y_pred_rfc)
auc_rfc = auc(fpr_rfc, tpr_rfc)

# adaboost
y_pred_abc = abc.predict_proba(test_x)[:,1]
fpr_abc, tpr_abc, thresholds_abc = roc_curve(test_y, y_pred_abc)
auc_abc = auc(fpr_abc, tpr_abc)

# Gradient Boost
y_pred_gbc = gbc.predict_proba(test_x)[:,1]
fpr_gbc, tpr_gbc, thresholds_gbc = roc_curve(test_y, y_pred_gbc)
auc_gbc = auc(fpr_gbc, tpr_gbc)

# XGboost
y_pred_xgb = xgb_clf.predict_proba(test_x)[:,1]
fpr_xgb, tpr_xgb, thresholds_xgb = roc_curve(test_y, y_pred_xgb)
auc_xgb = auc(fpr_xgb, tpr_xgb)

# %% [markdown]
# ### DNN model
# ##### Classification 1

# %%
model1 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(16, input_shape=(16,),activation='relu'),
    tf.keras.layers.BatchNormalization(),
    #tf.keras.layers.Dropout(0.5), 
    
    tf.keras.layers.Dense(12, input_shape=(16,),activation='relu'), 
    tf.keras.layers.BatchNormalization(axis=1, epsilon=0.001, center=True, scale=True, beta_initializer='zeros', gamma_initializer='ones'),
    #tf.keras.layers.Dropout(0.5),

    tf.keras.layers.Dense(9, input_shape=(12,),activation='relu'), 
    tf.keras.layers.BatchNormalization(axis=1, epsilon=0.001, center=True, scale=True, beta_initializer='zeros', gamma_initializer='ones'),
    #tf.keras.layers.Dropout(0.5),
    
    tf.keras.layers.Dense(5, input_shape=(9,),activation='relu'), 
    tf.keras.layers.BatchNormalization(axis=1, epsilon=0.001, center=True, scale=True, beta_initializer='zeros', gamma_initializer='ones'),
    #tf.keras.layers.Dropout(0.5),
    
    tf.keras.layers.Dense(2, input_shape=(5,),activation='relu'), 
    tf.keras.layers.BatchNormalization(axis=1, epsilon=0.001, center=True, scale=True, beta_initializer='zeros', gamma_initializer='ones'),
    #tf.keras.layers.Dropout(0.5),
    
    tf.keras.layers.Dense(1, input_shape=(2,),activation='sigmoid'),
])

model1.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /Users/huangeunchong/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /Users/huangeunchong/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
hist=model1.fit(train_x, train_y, batch_size=25, epochs=500)#,callbacks=[tensorboard]
# Out:
# Epoch 1/500
# 274/274 [==============================] - 2s 8ms/sample - loss: 0.8298 - acc: 0.4672
# Epoch 2/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.8348 - acc: 0.4453
# Epoch 3/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.7682 - acc: 0.5036
# Epoch 4/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.7746 - acc: 0.4927
# Epoch 5/500
# 274/274 [==============================] - 0s 248us/sample - loss: 0.7536 - acc: 0.4818
# Epoch 6/500
# 274/274 [==============================] - 0s 234us/sample - loss: 0.7105 - acc: 0.5803
# Epoch 7/500
# 274/274 [==============================] - 0s 228us/sample - loss: 0.7066 - acc: 0.5657
# Epoch 8/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.6643 - acc: 0.6168
# Epoch 9/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.6675 - acc: 0.5876
# Epoch 10/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.6493 - acc: 0.6314
# Epoch 11/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.6479 - acc: 0.6387
# Epoch 12/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.6485 - acc: 0.6095
# Epoch 13/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.6331 - acc: 0.6569
# Epoch 14/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.6347 - acc: 0.6423
# Epoch 15/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.6147 - acc: 0.6825
# Epoch 16/500
# 274/274 [==============================] - 0s 197us/sample - loss: 0.6114 - acc: 0.6715
# Epoch 17/500
# 274/274 [==============================] - 0s 199us/sample - loss: 0.6232 - acc: 0.6606
# Epoch 18/500
# 274/274 [==============================] - 0s 202us/sample - loss: 0.6132 - acc: 0.6971
# Epoch 19/500
# 274/274 [==============================] - 0s 199us/sample - loss: 0.6074 - acc: 0.6825
# Epoch 20/500
# 274/274 [==============================] - 0s 198us/sample - loss: 0.6032 - acc: 0.6934
# Epoch 21/500
# 274/274 [==============================] - 0s 197us/sample - loss: 0.5789 - acc: 0.7299
# Epoch 22/500
# 274/274 [==============================] - 0s 202us/sample - loss: 0.5980 - acc: 0.6898
# Epoch 23/500
# 274/274 [==============================] - 0s 198us/sample - loss: 0.5744 - acc: 0.7226
# Epoch 24/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.5787 - acc: 0.7080
# Epoch 25/500
# 274/274 [==============================] - 0s 241us/sample - loss: 0.5911 - acc: 0.7080
# Epoch 26/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.5703 - acc: 0.7263
# Epoch 27/500
# 274/274 [==============================] - 0s 232us/sample - loss: 0.5485 - acc: 0.7482
# Epoch 28/500
# 274/274 [==============================] - 0s 224us/sample - loss: 0.5420 - acc: 0.7518
# Epoch 29/500
# 274/274 [==============================] - 0s 242us/sample - loss: 0.5387 - acc: 0.7445
# Epoch 30/500
# 274/274 [==============================] - 0s 253us/sample - loss: 0.5274 - acc: 0.7701
# Epoch 31/500
# 274/274 [==============================] - 0s 237us/sample - loss: 0.5363 - acc: 0.7591
# Epoch 32/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.5332 - acc: 0.7591
# Epoch 33/500
# 274/274 [==============================] - 0s 282us/sample - loss: 0.5276 - acc: 0.7774
# Epoch 34/500
# 274/274 [==============================] - 0s 255us/sample - loss: 0.5200 - acc: 0.7737
# Epoch 35/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.5119 - acc: 0.7701
# Epoch 36/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.5068 - acc: 0.7774
# Epoch 37/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.5308 - acc: 0.7664
# Epoch 38/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.5061 - acc: 0.7920
# Epoch 39/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.5068 - acc: 0.7847
# Epoch 40/500
# 274/274 [==============================] - 0s 195us/sample - loss: 0.4806 - acc: 0.7993
# Epoch 41/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.4868 - acc: 0.7993
# Epoch 42/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.4957 - acc: 0.7847
# Epoch 43/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.4745 - acc: 0.8139
# Epoch 44/500
# 274/274 [==============================] - 0s 197us/sample - loss: 0.4611 - acc: 0.8102
# Epoch 45/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.4870 - acc: 0.7920
# Epoch 46/500
# 274/274 [==============================] - 0s 195us/sample - loss: 0.4627 - acc: 0.7883
# Epoch 47/500
# 274/274 [==============================] - 0s 195us/sample - loss: 0.4551 - acc: 0.8139
# Epoch 48/500
# 274/274 [==============================] - 0s 202us/sample - loss: 0.4595 - acc: 0.7956
# Epoch 49/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.4418 - acc: 0.8029
# Epoch 50/500
# 274/274 [==============================] - 0s 202us/sample - loss: 0.4307 - acc: 0.8431
# Epoch 51/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.4346 - acc: 0.8285
# Epoch 52/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.4105 - acc: 0.8321
# Epoch 53/500
# 274/274 [==============================] - 0s 229us/sample - loss: 0.4295 - acc: 0.8358
# Epoch 54/500
# 274/274 [==============================] - 0s 234us/sample - loss: 0.4103 - acc: 0.8540
# Epoch 55/500
# 274/274 [==============================] - 0s 231us/sample - loss: 0.3989 - acc: 0.8504
# Epoch 56/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.4068 - acc: 0.8358
# Epoch 57/500
# 274/274 [==============================] - 0s 257us/sample - loss: 0.3963 - acc: 0.8540
# Epoch 58/500
# 274/274 [==============================] - 0s 257us/sample - loss: 0.4227 - acc: 0.8212
# Epoch 59/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.3690 - acc: 0.8686
# Epoch 60/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.3735 - acc: 0.8650
# Epoch 61/500
# 274/274 [==============================] - 0s 197us/sample - loss: 0.3843 - acc: 0.8540
# Epoch 62/500
# 274/274 [==============================] - 0s 199us/sample - loss: 0.3836 - acc: 0.8613
# Epoch 63/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.3594 - acc: 0.8577
# Epoch 64/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.3628 - acc: 0.8686
# Epoch 65/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.3343 - acc: 0.9015
# Epoch 66/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.3624 - acc: 0.8540
# Epoch 67/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.3292 - acc: 0.8869
# Epoch 68/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.3418 - acc: 0.8832
# Epoch 69/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.3404 - acc: 0.8905
# Epoch 70/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.3303 - acc: 0.8869
# Epoch 71/500
# 274/274 [==============================] - 0s 225us/sample - loss: 0.3202 - acc: 0.8978
# Epoch 72/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.3485 - acc: 0.8723
# Epoch 73/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.3028 - acc: 0.9124
# Epoch 74/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.3003 - acc: 0.9124
# Epoch 75/500
# 274/274 [==============================] - 0s 266us/sample - loss: 0.3009 - acc: 0.9088
# Epoch 76/500
# 274/274 [==============================] - 0s 247us/sample - loss: 0.3106 - acc: 0.9088
# Epoch 77/500
# 274/274 [==============================] - 0s 233us/sample - loss: 0.3119 - acc: 0.9015
# Epoch 78/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.2728 - acc: 0.9234
# Epoch 79/500
# 274/274 [==============================] - 0s 239us/sample - loss: 0.3076 - acc: 0.8978
# Epoch 80/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.2814 - acc: 0.9051
# Epoch 81/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.2754 - acc: 0.9124
# Epoch 82/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.2601 - acc: 0.9197
# Epoch 83/500
# 274/274 [==============================] - 0s 232us/sample - loss: 0.2739 - acc: 0.9015
# Epoch 84/500
# 274/274 [==============================] - 0s 250us/sample - loss: 0.3030 - acc: 0.9051
# Epoch 85/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.2821 - acc: 0.9234
# Epoch 86/500
# 274/274 [==============================] - 0s 235us/sample - loss: 0.3622 - acc: 0.8613
# Epoch 87/500
# 274/274 [==============================] - 0s 242us/sample - loss: 0.2760 - acc: 0.9015
# Epoch 88/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.2364 - acc: 0.9343
# Epoch 89/500
# 274/274 [==============================] - 0s 232us/sample - loss: 0.2450 - acc: 0.9453
# Epoch 90/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.2392 - acc: 0.9416
# Epoch 91/500
# 274/274 [==============================] - 0s 224us/sample - loss: 0.2515 - acc: 0.9453
# Epoch 92/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.2385 - acc: 0.9234
# Epoch 93/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.2284 - acc: 0.9416
# Epoch 94/500
# 274/274 [==============================] - 0s 195us/sample - loss: 0.2562 - acc: 0.9234
# Epoch 95/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.2332 - acc: 0.9270
# Epoch 96/500
# 274/274 [==============================] - 0s 193us/sample - loss: 0.2211 - acc: 0.9416
# Epoch 97/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.2598 - acc: 0.9161
# Epoch 98/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.2263 - acc: 0.9307
# Epoch 99/500
# 274/274 [==============================] - 0s 260us/sample - loss: 0.2506 - acc: 0.9015
# Epoch 100/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.2436 - acc: 0.9307
# Epoch 101/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.2518 - acc: 0.9270
# Epoch 102/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.2123 - acc: 0.9453
# Epoch 103/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.2191 - acc: 0.9307
# Epoch 104/500
# 274/274 [==============================] - 0s 220us/sample - loss: 0.2284 - acc: 0.9161
# Epoch 105/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.2214 - acc: 0.9307
# Epoch 106/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.1908 - acc: 0.9562
# Epoch 107/500
# 274/274 [==============================] - 0s 202us/sample - loss: 0.2092 - acc: 0.9343
# Epoch 108/500
# 274/274 [==============================] - 0s 197us/sample - loss: 0.1729 - acc: 0.9526
# Epoch 109/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.1945 - acc: 0.9526
# Epoch 110/500
# 274/274 [==============================] - 0s 202us/sample - loss: 0.1909 - acc: 0.9599
# Epoch 111/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.1798 - acc: 0.9599
# Epoch 112/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.1698 - acc: 0.9635
# Epoch 113/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.2306 - acc: 0.9343
# Epoch 114/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.1760 - acc: 0.9562
# Epoch 115/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.1955 - acc: 0.9489
# Epoch 116/500
# 274/274 [==============================] - 0s 199us/sample - loss: 0.1866 - acc: 0.9489
# Epoch 117/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.2258 - acc: 0.9234
# Epoch 118/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.2004 - acc: 0.9307
# Epoch 119/500
# 274/274 [==============================] - 0s 198us/sample - loss: 0.1793 - acc: 0.9343
# Epoch 120/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.1792 - acc: 0.9380
# Epoch 121/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.1635 - acc: 0.9672
# Epoch 122/500
# 274/274 [==============================] - 0s 198us/sample - loss: 0.1887 - acc: 0.9489
# Epoch 123/500
# 274/274 [==============================] - 0s 198us/sample - loss: 0.1958 - acc: 0.9380
# Epoch 124/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.2057 - acc: 0.9270
# Epoch 125/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.1624 - acc: 0.9526
# Epoch 126/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.1865 - acc: 0.9453
# Epoch 127/500
# 274/274 [==============================] - 0s 202us/sample - loss: 0.1378 - acc: 0.9635
# Epoch 128/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.2010 - acc: 0.9416
# Epoch 129/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.1454 - acc: 0.9672
# Epoch 130/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.1955 - acc: 0.9380
# Epoch 131/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.1518 - acc: 0.9599
# Epoch 132/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.1691 - acc: 0.9489
# Epoch 133/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.1492 - acc: 0.9599
# Epoch 134/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.1656 - acc: 0.9489
# Epoch 135/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.1217 - acc: 0.9818
# Epoch 136/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.1858 - acc: 0.9526
# Epoch 137/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.1466 - acc: 0.9672
# Epoch 138/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.1510 - acc: 0.9562
# Epoch 139/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.1606 - acc: 0.9599
# Epoch 140/500
# 274/274 [==============================] - 0s 229us/sample - loss: 0.1659 - acc: 0.9526
# Epoch 141/500
# 274/274 [==============================] - 0s 250us/sample - loss: 0.1532 - acc: 0.9708
# Epoch 142/500
# 274/274 [==============================] - 0s 250us/sample - loss: 0.1927 - acc: 0.9234
# Epoch 143/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.1429 - acc: 0.9599
# Epoch 144/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.1410 - acc: 0.9745
# Epoch 145/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.1524 - acc: 0.9562
# Epoch 146/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.1777 - acc: 0.9416
# Epoch 147/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.1544 - acc: 0.9635
# Epoch 148/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.1557 - acc: 0.9635
# Epoch 149/500
# 274/274 [==============================] - 0s 242us/sample - loss: 0.1491 - acc: 0.9635
# Epoch 150/500
# 274/274 [==============================] - 0s 234us/sample - loss: 0.1557 - acc: 0.9453
# Epoch 151/500
# 274/274 [==============================] - 0s 239us/sample - loss: 0.1233 - acc: 0.9708
# Epoch 152/500
# 274/274 [==============================] - 0s 223us/sample - loss: 0.1725 - acc: 0.9489
# Epoch 153/500
# 274/274 [==============================] - 0s 227us/sample - loss: 0.1354 - acc: 0.9562
# Epoch 154/500
# 274/274 [==============================] - 0s 229us/sample - loss: 0.1363 - acc: 0.9635
# Epoch 155/500
# 274/274 [==============================] - 0s 227us/sample - loss: 0.1145 - acc: 0.9708
# Epoch 156/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.1672 - acc: 0.9526
# Epoch 157/500
# 274/274 [==============================] - 0s 220us/sample - loss: 0.1442 - acc: 0.9526
# Epoch 158/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.1401 - acc: 0.9562
# Epoch 159/500
# 274/274 [==============================] - 0s 243us/sample - loss: 0.1195 - acc: 0.9781
# Epoch 160/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.1599 - acc: 0.9489
# Epoch 161/500
# 274/274 [==============================] - 0s 220us/sample - loss: 0.1848 - acc: 0.9489
# Epoch 162/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.1260 - acc: 0.9599
# Epoch 163/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.1234 - acc: 0.9708
# Epoch 164/500
# 274/274 [==============================] - 0s 233us/sample - loss: 0.1129 - acc: 0.9708
# Epoch 165/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.1140 - acc: 0.9672
# Epoch 166/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.1058 - acc: 0.9745
# Epoch 167/500
# 274/274 [==============================] - 0s 241us/sample - loss: 0.1176 - acc: 0.9672
# Epoch 168/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.1455 - acc: 0.9453
# Epoch 169/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.1337 - acc: 0.9526
# Epoch 170/500
# 274/274 [==============================] - 0s 234us/sample - loss: 0.1084 - acc: 0.9672
# Epoch 171/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.0995 - acc: 0.9781
# Epoch 172/500
# 274/274 [==============================] - 0s 222us/sample - loss: 0.1152 - acc: 0.9745
# Epoch 173/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.1065 - acc: 0.9708
# Epoch 174/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.1048 - acc: 0.9745
# Epoch 175/500
# 274/274 [==============================] - 0s 234us/sample - loss: 0.1183 - acc: 0.9708
# Epoch 176/500
# 274/274 [==============================] - 0s 242us/sample - loss: 0.1020 - acc: 0.9708
# Epoch 177/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.1210 - acc: 0.9599
# Epoch 178/500
# 274/274 [==============================] - 0s 241us/sample - loss: 0.1277 - acc: 0.9635
# Epoch 179/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.1298 - acc: 0.9672
# Epoch 180/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.1029 - acc: 0.9745
# Epoch 181/500
# 274/274 [==============================] - 0s 240us/sample - loss: 0.0919 - acc: 0.9818
# Epoch 182/500
# 274/274 [==============================] - 0s 229us/sample - loss: 0.1271 - acc: 0.9599
# Epoch 183/500
# 274/274 [==============================] - 0s 235us/sample - loss: 0.1128 - acc: 0.9745
# Epoch 184/500
# 274/274 [==============================] - 0s 233us/sample - loss: 0.1065 - acc: 0.9708
# Epoch 185/500
# 274/274 [==============================] - 0s 232us/sample - loss: 0.1241 - acc: 0.9526
# Epoch 186/500
# 274/274 [==============================] - 0s 222us/sample - loss: 0.1276 - acc: 0.9526
# Epoch 187/500
# 274/274 [==============================] - 0s 247us/sample - loss: 0.0871 - acc: 0.9818
# Epoch 188/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.1520 - acc: 0.9562
# Epoch 189/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.1433 - acc: 0.9526
# Epoch 190/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.1014 - acc: 0.9745
# Epoch 191/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.1080 - acc: 0.9781
# Epoch 192/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.1568 - acc: 0.9453
# Epoch 193/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.0815 - acc: 0.9818
# Epoch 194/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0887 - acc: 0.9745
# Epoch 195/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.1099 - acc: 0.9781
# Epoch 196/500
# 274/274 [==============================] - 0s 199us/sample - loss: 0.0896 - acc: 0.9818
# Epoch 197/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0986 - acc: 0.9745
# Epoch 198/500
# 274/274 [==============================] - 0s 248us/sample - loss: 0.1440 - acc: 0.9526
# Epoch 199/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.1224 - acc: 0.9708
# Epoch 200/500
# 274/274 [==============================] - 0s 227us/sample - loss: 0.0989 - acc: 0.9745
# Epoch 201/500
# 274/274 [==============================] - 0s 232us/sample - loss: 0.0812 - acc: 0.9745
# Epoch 202/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.1070 - acc: 0.9745
# Epoch 203/500
# 274/274 [==============================] - 0s 232us/sample - loss: 0.0832 - acc: 0.9854
# Epoch 204/500
# 274/274 [==============================] - 0s 234us/sample - loss: 0.0945 - acc: 0.9745
# Epoch 205/500
# 274/274 [==============================] - 0s 234us/sample - loss: 0.0716 - acc: 0.9854
# Epoch 206/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.0590 - acc: 0.9854
# Epoch 207/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.0897 - acc: 0.9672
# Epoch 208/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.1141 - acc: 0.9562
# Epoch 209/500
# 274/274 [==============================] - 0s 199us/sample - loss: 0.0801 - acc: 0.9854
# Epoch 210/500
# 274/274 [==============================] - 0s 198us/sample - loss: 0.1227 - acc: 0.9635
# Epoch 211/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0843 - acc: 0.9854
# Epoch 212/500
# 274/274 [==============================] - 0s 231us/sample - loss: 0.1772 - acc: 0.9416
# Epoch 213/500
# 274/274 [==============================] - 0s 233us/sample - loss: 0.0721 - acc: 0.9818
# Epoch 214/500
# 274/274 [==============================] - 0s 233us/sample - loss: 0.0884 - acc: 0.9708
# Epoch 215/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0707 - acc: 0.9854
# Epoch 216/500
# 274/274 [==============================] - 0s 250us/sample - loss: 0.1336 - acc: 0.9562
# Epoch 217/500
# 274/274 [==============================] - 0s 240us/sample - loss: 0.0956 - acc: 0.9745
# Epoch 218/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.0744 - acc: 0.9818
# Epoch 219/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.1082 - acc: 0.9635
# Epoch 220/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0959 - acc: 0.9672
# Epoch 221/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0635 - acc: 0.9891
# Epoch 222/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0862 - acc: 0.9781
# Epoch 223/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.0925 - acc: 0.9708
# Epoch 224/500
# 274/274 [==============================] - 0s 201us/sample - loss: 0.0919 - acc: 0.9818
# Epoch 225/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.0645 - acc: 0.9854
# Epoch 226/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0615 - acc: 0.9891
# Epoch 227/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0791 - acc: 0.9745
# Epoch 228/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.1115 - acc: 0.9635
# Epoch 229/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.0636 - acc: 0.9891
# Epoch 230/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0923 - acc: 0.9635
# Epoch 231/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.0661 - acc: 0.9891
# Epoch 232/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.0535 - acc: 0.9927
# Epoch 233/500
# 274/274 [==============================] - 0s 228us/sample - loss: 0.0540 - acc: 0.9818
# Epoch 234/500
# 274/274 [==============================] - 0s 220us/sample - loss: 0.0719 - acc: 0.9891
# Epoch 235/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.0698 - acc: 0.9818
# Epoch 236/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.0949 - acc: 0.9781
# Epoch 237/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0861 - acc: 0.9672
# Epoch 238/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.0740 - acc: 0.9745
# Epoch 239/500
# 274/274 [==============================] - 0s 220us/sample - loss: 0.0565 - acc: 0.9854
# Epoch 240/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.0617 - acc: 0.9818
# Epoch 241/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0633 - acc: 0.9891
# Epoch 242/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.1191 - acc: 0.9672
# Epoch 243/500
# 274/274 [==============================] - 0s 198us/sample - loss: 0.0745 - acc: 0.9818
# Epoch 244/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.0657 - acc: 0.9854
# Epoch 245/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.1004 - acc: 0.9599
# Epoch 246/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.0602 - acc: 0.9854
# Epoch 247/500
# 274/274 [==============================] - 0s 196us/sample - loss: 0.1283 - acc: 0.9562
# Epoch 248/500
# 274/274 [==============================] - 0s 197us/sample - loss: 0.1181 - acc: 0.9599
# Epoch 249/500
# 274/274 [==============================] - 0s 198us/sample - loss: 0.0896 - acc: 0.9672
# Epoch 250/500
# 274/274 [==============================] - 0s 234us/sample - loss: 0.0530 - acc: 0.9891
# Epoch 251/500
# 274/274 [==============================] - 0s 235us/sample - loss: 0.0883 - acc: 0.9745
# Epoch 252/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.0885 - acc: 0.9708
# Epoch 253/500
# 274/274 [==============================] - 0s 222us/sample - loss: 0.1263 - acc: 0.9708
# Epoch 254/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0458 - acc: 0.9891
# Epoch 255/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.0579 - acc: 0.9891
# Epoch 256/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0439 - acc: 0.9964
# Epoch 257/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.0626 - acc: 0.9781
# Epoch 258/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0761 - acc: 0.9854
# Epoch 259/500
# 274/274 [==============================] - 0s 195us/sample - loss: 0.0348 - acc: 0.9964
# Epoch 260/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.0708 - acc: 0.9781
# Epoch 261/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0597 - acc: 0.9781
# Epoch 262/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0729 - acc: 0.9745
# Epoch 263/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0891 - acc: 0.9745
# Epoch 264/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0959 - acc: 0.9635
# Epoch 265/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0638 - acc: 0.9891
# Epoch 266/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.1175 - acc: 0.9672
# Epoch 267/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.0885 - acc: 0.9818
# Epoch 268/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.1313 - acc: 0.9635
# Epoch 269/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0979 - acc: 0.9672
# Epoch 270/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.0451 - acc: 0.9818
# Epoch 271/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0385 - acc: 0.9927
# Epoch 272/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0467 - acc: 0.9854
# Epoch 273/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0513 - acc: 0.9891
# Epoch 274/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.0901 - acc: 0.9672
# Epoch 275/500
# 274/274 [==============================] - 0s 232us/sample - loss: 0.0325 - acc: 0.9964
# Epoch 276/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.0373 - acc: 0.9891
# Epoch 277/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.0566 - acc: 0.9781
# Epoch 278/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.0488 - acc: 0.9854
# Epoch 279/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.0552 - acc: 0.9854
# Epoch 280/500
# 274/274 [==============================] - 0s 243us/sample - loss: 0.1014 - acc: 0.9562
# Epoch 281/500
# 274/274 [==============================] - 0s 231us/sample - loss: 0.0848 - acc: 0.9562
# Epoch 282/500
# 274/274 [==============================] - 0s 236us/sample - loss: 0.0596 - acc: 0.9818
# Epoch 283/500
# 274/274 [==============================] - 0s 227us/sample - loss: 0.0738 - acc: 0.9781
# Epoch 284/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.0562 - acc: 0.9818
# Epoch 285/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.1682 - acc: 0.9416
# Epoch 286/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0969 - acc: 0.9599
# Epoch 287/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0505 - acc: 0.9854
# Epoch 288/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0903 - acc: 0.9672
# Epoch 289/500
# 274/274 [==============================] - 0s 194us/sample - loss: 0.0677 - acc: 0.9818
# Epoch 290/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.0434 - acc: 0.9891
# Epoch 291/500
# 274/274 [==============================] - 0s 222us/sample - loss: 0.0830 - acc: 0.9708
# Epoch 292/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.0609 - acc: 0.9818
# Epoch 293/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0582 - acc: 0.9854
# Epoch 294/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.0563 - acc: 0.9854
# Epoch 295/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0809 - acc: 0.9672
# Epoch 296/500
# 274/274 [==============================] - 0s 202us/sample - loss: 0.0317 - acc: 0.9964
# Epoch 297/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0447 - acc: 0.9927
# Epoch 298/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.0406 - acc: 0.9891
# Epoch 299/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0917 - acc: 0.9672
# Epoch 300/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0513 - acc: 0.9891
# Epoch 301/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0561 - acc: 0.9818
# Epoch 302/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.0401 - acc: 0.9927
# Epoch 303/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0393 - acc: 0.9964
# Epoch 304/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0473 - acc: 0.9854
# Epoch 305/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0554 - acc: 0.9854
# Epoch 306/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.1553 - acc: 0.9489
# Epoch 307/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.0247 - acc: 1.0000
# Epoch 308/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0720 - acc: 0.9781
# Epoch 309/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0556 - acc: 0.9745
# Epoch 310/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0624 - acc: 0.9708
# Epoch 311/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0431 - acc: 0.9854
# Epoch 312/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.0470 - acc: 0.9818
# Epoch 313/500
# 274/274 [==============================] - 0s 240us/sample - loss: 0.0382 - acc: 0.9927
# Epoch 314/500
# 274/274 [==============================] - 0s 229us/sample - loss: 0.0341 - acc: 0.9927
# Epoch 315/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0592 - acc: 0.9891
# Epoch 316/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.1028 - acc: 0.9672
# Epoch 317/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.1109 - acc: 0.9562
# Epoch 318/500
# 274/274 [==============================] - 0s 220us/sample - loss: 0.0564 - acc: 0.9854
# Epoch 319/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0642 - acc: 0.9818
# Epoch 320/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.0503 - acc: 0.9854
# Epoch 321/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0779 - acc: 0.9745
# Epoch 322/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0670 - acc: 0.9781
# Epoch 323/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0504 - acc: 0.9891
# Epoch 324/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0583 - acc: 0.9818
# Epoch 325/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0411 - acc: 0.9891
# Epoch 326/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.0294 - acc: 0.9964
# Epoch 327/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.0234 - acc: 1.0000
# Epoch 328/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.0425 - acc: 0.9891
# Epoch 329/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0575 - acc: 0.9818
# Epoch 330/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.0484 - acc: 0.9854
# Epoch 331/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0720 - acc: 0.9635
# Epoch 332/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0398 - acc: 0.9927
# Epoch 333/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.0629 - acc: 0.9745
# Epoch 334/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0842 - acc: 0.9708
# Epoch 335/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0402 - acc: 0.9927
# Epoch 336/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0817 - acc: 0.9781
# Epoch 337/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.0353 - acc: 0.9927
# Epoch 338/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.0387 - acc: 0.9927
# Epoch 339/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.0667 - acc: 0.9818
# Epoch 340/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0481 - acc: 0.9854
# Epoch 341/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.0285 - acc: 0.9891
# Epoch 342/500
# 274/274 [==============================] - 0s 242us/sample - loss: 0.0388 - acc: 0.9964
# Epoch 343/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0366 - acc: 0.9927
# Epoch 344/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.0174 - acc: 1.0000
# Epoch 345/500
# 274/274 [==============================] - 0s 243us/sample - loss: 0.0479 - acc: 0.9891
# Epoch 346/500
# 274/274 [==============================] - 0s 234us/sample - loss: 0.0337 - acc: 0.9927
# Epoch 347/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.0447 - acc: 0.9927
# Epoch 348/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0420 - acc: 0.9854
# Epoch 349/500
# 274/274 [==============================] - 0s 254us/sample - loss: 0.0487 - acc: 0.9854
# Epoch 350/500
# 274/274 [==============================] - 0s 231us/sample - loss: 0.0361 - acc: 0.9927
# Epoch 351/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.0446 - acc: 0.9891
# Epoch 352/500
# 274/274 [==============================] - 0s 223us/sample - loss: 0.0383 - acc: 0.9891
# Epoch 353/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.0533 - acc: 0.9781
# Epoch 354/500
# 274/274 [==============================] - 0s 228us/sample - loss: 0.0292 - acc: 0.9964
# Epoch 355/500
# 274/274 [==============================] - 0s 242us/sample - loss: 0.0738 - acc: 0.9745
# Epoch 356/500
# 274/274 [==============================] - 0s 222us/sample - loss: 0.0483 - acc: 0.9927
# Epoch 357/500
# 274/274 [==============================] - 0s 222us/sample - loss: 0.0204 - acc: 0.9964
# Epoch 358/500
# 274/274 [==============================] - 0s 201us/sample - loss: 0.0548 - acc: 0.9781
# Epoch 359/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0388 - acc: 0.9891
# Epoch 360/500
# 274/274 [==============================] - 0s 201us/sample - loss: 0.0576 - acc: 0.9854
# Epoch 361/500
# 274/274 [==============================] - 0s 220us/sample - loss: 0.0506 - acc: 0.9818
# Epoch 362/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.0853 - acc: 0.9745
# Epoch 363/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.0525 - acc: 0.9818
# Epoch 364/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0536 - acc: 0.9781
# Epoch 365/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0377 - acc: 0.9891
# Epoch 366/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.0260 - acc: 0.9964
# Epoch 367/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0471 - acc: 0.9781
# Epoch 368/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.0406 - acc: 0.9927
# Epoch 369/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.1093 - acc: 0.9635
# Epoch 370/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.0555 - acc: 0.9708
# Epoch 371/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0575 - acc: 0.9818
# Epoch 372/500
# 274/274 [==============================] - 0s 235us/sample - loss: 0.0730 - acc: 0.9781
# Epoch 373/500
# 274/274 [==============================] - 0s 216us/sample - loss: 0.0605 - acc: 0.9781
# Epoch 374/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0266 - acc: 0.9964
# Epoch 375/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.0293 - acc: 0.9891
# Epoch 376/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0700 - acc: 0.9745
# Epoch 377/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.1273 - acc: 0.9635
# Epoch 378/500
# 274/274 [==============================] - 0s 249us/sample - loss: 0.0710 - acc: 0.9781
# Epoch 379/500
# 274/274 [==============================] - 0s 250us/sample - loss: 0.0363 - acc: 0.9927
# Epoch 380/500
# 274/274 [==============================] - 0s 228us/sample - loss: 0.0402 - acc: 0.9891
# Epoch 381/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.0646 - acc: 0.9781
# Epoch 382/500
# 274/274 [==============================] - 0s 224us/sample - loss: 0.0267 - acc: 0.9964
# Epoch 383/500
# 274/274 [==============================] - 0s 233us/sample - loss: 0.0379 - acc: 0.9927
# Epoch 384/500
# 274/274 [==============================] - 0s 246us/sample - loss: 0.0346 - acc: 0.9891
# Epoch 385/500
# 274/274 [==============================] - 0s 252us/sample - loss: 0.0290 - acc: 0.9927
# Epoch 386/500
# 274/274 [==============================] - 0s 246us/sample - loss: 0.0240 - acc: 0.9964
# Epoch 387/500
# 274/274 [==============================] - 0s 242us/sample - loss: 0.0525 - acc: 0.9854
# Epoch 388/500
# 274/274 [==============================] - 0s 251us/sample - loss: 0.1051 - acc: 0.9708
# Epoch 389/500
# 274/274 [==============================] - 0s 244us/sample - loss: 0.0189 - acc: 1.0000
# Epoch 390/500
# 274/274 [==============================] - 0s 237us/sample - loss: 0.0279 - acc: 0.9964
# Epoch 391/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.0302 - acc: 0.9927
# Epoch 392/500
# 274/274 [==============================] - 0s 214us/sample - loss: 0.0739 - acc: 0.9818
# Epoch 393/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0370 - acc: 0.9927
# Epoch 394/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.0478 - acc: 0.9818
# Epoch 395/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.0955 - acc: 0.9672
# Epoch 396/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0156 - acc: 1.0000
# Epoch 397/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0548 - acc: 0.9818
# Epoch 398/500
# 274/274 [==============================] - 0s 224us/sample - loss: 0.0554 - acc: 0.9745
# Epoch 399/500
# 274/274 [==============================] - 0s 226us/sample - loss: 0.0502 - acc: 0.9891
# Epoch 400/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0350 - acc: 0.9891
# Epoch 401/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0248 - acc: 0.9964
# Epoch 402/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0284 - acc: 0.9927
# Epoch 403/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0173 - acc: 1.0000
# Epoch 404/500
# 274/274 [==============================] - 0s 201us/sample - loss: 0.0261 - acc: 0.9927
# Epoch 405/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0536 - acc: 0.9745
# Epoch 406/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.0409 - acc: 0.9854
# Epoch 407/500
# 274/274 [==============================] - 0s 247us/sample - loss: 0.0513 - acc: 0.9745
# Epoch 408/500
# 274/274 [==============================] - 0s 232us/sample - loss: 0.0142 - acc: 1.0000
# Epoch 409/500
# 274/274 [==============================] - 0s 235us/sample - loss: 0.0362 - acc: 0.9891
# Epoch 410/500
# 274/274 [==============================] - 0s 231us/sample - loss: 0.0318 - acc: 0.9891
# Epoch 411/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.0121 - acc: 1.0000
# Epoch 412/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0240 - acc: 0.9927
# Epoch 413/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.0444 - acc: 0.9818
# Epoch 414/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.0500 - acc: 0.9818
# Epoch 415/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0183 - acc: 0.9927
# Epoch 416/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0287 - acc: 0.9927
# Epoch 417/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0608 - acc: 0.9708
# Epoch 418/500
# 274/274 [==============================] - 0s 229us/sample - loss: 0.0659 - acc: 0.9781
# Epoch 419/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.0514 - acc: 0.9818
# Epoch 420/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0597 - acc: 0.9891
# Epoch 421/500
# 274/274 [==============================] - 0s 225us/sample - loss: 0.0110 - acc: 1.0000
# Epoch 422/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0339 - acc: 0.9964
# Epoch 423/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0211 - acc: 0.9964
# Epoch 424/500
# 274/274 [==============================] - 0s 197us/sample - loss: 0.0301 - acc: 0.9927
# Epoch 425/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0540 - acc: 0.9818
# Epoch 426/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0360 - acc: 0.9891
# Epoch 427/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0215 - acc: 1.0000
# Epoch 428/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0261 - acc: 0.9927
# Epoch 429/500
# 274/274 [==============================] - 0s 253us/sample - loss: 0.0376 - acc: 0.9927
# Epoch 430/500
# 274/274 [==============================] - 0s 245us/sample - loss: 0.0641 - acc: 0.9635
# Epoch 431/500
# 274/274 [==============================] - 0s 243us/sample - loss: 0.0634 - acc: 0.9745
# Epoch 432/500
# 274/274 [==============================] - 0s 233us/sample - loss: 0.0702 - acc: 0.9818
# Epoch 433/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.0142 - acc: 1.0000
# Epoch 434/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0573 - acc: 0.9781
# Epoch 435/500
# 274/274 [==============================] - 0s 206us/sample - loss: 0.0283 - acc: 0.9927
# Epoch 436/500
# 274/274 [==============================] - 0s 199us/sample - loss: 0.0245 - acc: 0.9927
# Epoch 437/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.0850 - acc: 0.9708
# Epoch 438/500
# 274/274 [==============================] - 0s 239us/sample - loss: 0.0248 - acc: 0.9927
# Epoch 439/500
# 274/274 [==============================] - 0s 229us/sample - loss: 0.0587 - acc: 0.9891
# Epoch 440/500
# 274/274 [==============================] - 0s 255us/sample - loss: 0.0447 - acc: 0.9781
# Epoch 441/500
# 274/274 [==============================] - 0s 301us/sample - loss: 0.1696 - acc: 0.9526
# Epoch 442/500
# 274/274 [==============================] - 0s 220us/sample - loss: 0.0282 - acc: 0.9927
# Epoch 443/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0425 - acc: 0.9854
# Epoch 444/500
# 274/274 [==============================] - 0s 233us/sample - loss: 0.0327 - acc: 0.9964
# Epoch 445/500
# 274/274 [==============================] - 0s 254us/sample - loss: 0.0248 - acc: 0.9854
# Epoch 446/500
# 274/274 [==============================] - 0s 256us/sample - loss: 0.0247 - acc: 0.9927
# Epoch 447/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.1235 - acc: 0.9672
# Epoch 448/500
# 274/274 [==============================] - 0s 200us/sample - loss: 0.0379 - acc: 0.9891
# Epoch 449/500
# 274/274 [==============================] - 0s 225us/sample - loss: 0.0417 - acc: 0.9818
# Epoch 450/500
# 274/274 [==============================] - 0s 239us/sample - loss: 0.0615 - acc: 0.9818
# Epoch 451/500
# 274/274 [==============================] - 0s 219us/sample - loss: 0.0662 - acc: 0.9818
# Epoch 452/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0165 - acc: 0.9964
# Epoch 453/500
# 274/274 [==============================] - 0s 199us/sample - loss: 0.0137 - acc: 0.9964
# Epoch 454/500
# 274/274 [==============================] - 0s 201us/sample - loss: 0.0236 - acc: 0.9927
# Epoch 455/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.0790 - acc: 0.9781
# Epoch 456/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.1144 - acc: 0.9635
# Epoch 457/500
# 274/274 [==============================] - 0s 236us/sample - loss: 0.0884 - acc: 0.9708
# Epoch 458/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.0130 - acc: 1.0000
# Epoch 459/500
# 274/274 [==============================] - 0s 209us/sample - loss: 0.0870 - acc: 0.9708
# Epoch 460/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.0214 - acc: 0.9964
# Epoch 461/500
# 274/274 [==============================] - 0s 220us/sample - loss: 0.0223 - acc: 0.9927
# Epoch 462/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0178 - acc: 1.0000
# Epoch 463/500
# 274/274 [==============================] - 0s 217us/sample - loss: 0.0291 - acc: 0.9854
# Epoch 464/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0295 - acc: 0.9927
# Epoch 465/500
# 274/274 [==============================] - 0s 221us/sample - loss: 0.0244 - acc: 1.0000
# Epoch 466/500
# 274/274 [==============================] - 0s 227us/sample - loss: 0.0354 - acc: 0.9891
# Epoch 467/500
# 274/274 [==============================] - 0s 233us/sample - loss: 0.0206 - acc: 0.9964
# Epoch 468/500
# 274/274 [==============================] - 0s 218us/sample - loss: 0.0237 - acc: 0.9964
# Epoch 469/500
# 274/274 [==============================] - 0s 211us/sample - loss: 0.0472 - acc: 0.9854
# Epoch 470/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0178 - acc: 0.9964
# Epoch 471/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0177 - acc: 0.9964
# Epoch 472/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0850 - acc: 0.9745
# Epoch 473/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0299 - acc: 0.9964
# Epoch 474/500
# 274/274 [==============================] - 0s 232us/sample - loss: 0.0216 - acc: 0.9927
# Epoch 475/500
# 274/274 [==============================] - 0s 238us/sample - loss: 0.0550 - acc: 0.9781
# Epoch 476/500
# 274/274 [==============================] - 0s 247us/sample - loss: 0.0315 - acc: 0.9854
# Epoch 477/500
# 274/274 [==============================] - 0s 230us/sample - loss: 0.0300 - acc: 0.9854
# Epoch 478/500
# 274/274 [==============================] - 0s 231us/sample - loss: 0.0244 - acc: 0.9891
# Epoch 479/500
# 274/274 [==============================] - 0s 210us/sample - loss: 0.0273 - acc: 0.9854
# Epoch 480/500
# 274/274 [==============================] - 0s 224us/sample - loss: 0.0396 - acc: 0.9891
# Epoch 481/500
# 274/274 [==============================] - 0s 235us/sample - loss: 0.0179 - acc: 0.9964
# Epoch 482/500
# 274/274 [==============================] - 0s 240us/sample - loss: 0.0469 - acc: 0.9891
# Epoch 483/500
# 274/274 [==============================] - 0s 245us/sample - loss: 0.0770 - acc: 0.9708
# Epoch 484/500
# 274/274 [==============================] - 0s 236us/sample - loss: 0.0293 - acc: 0.9927
# Epoch 485/500
# 274/274 [==============================] - 0s 222us/sample - loss: 0.0453 - acc: 0.9854
# Epoch 486/500
# 274/274 [==============================] - 0s 203us/sample - loss: 0.0462 - acc: 0.9745
# Epoch 487/500
# 274/274 [==============================] - 0s 235us/sample - loss: 0.0322 - acc: 0.9818
# Epoch 488/500
# 274/274 [==============================] - 0s 231us/sample - loss: 0.0352 - acc: 0.9927
# Epoch 489/500
# 274/274 [==============================] - 0s 208us/sample - loss: 0.0245 - acc: 0.9964
# Epoch 490/500
# 274/274 [==============================] - 0s 199us/sample - loss: 0.0326 - acc: 0.9891
# Epoch 491/500
# 274/274 [==============================] - 0s 201us/sample - loss: 0.0394 - acc: 0.9854
# Epoch 492/500
# 274/274 [==============================] - 0s 212us/sample - loss: 0.0404 - acc: 0.9854
# Epoch 493/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0797 - acc: 0.9745
# Epoch 494/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0142 - acc: 0.9964
# Epoch 495/500
# 274/274 [==============================] - 0s 207us/sample - loss: 0.0381 - acc: 0.9891
# Epoch 496/500
# 274/274 [==============================] - 0s 205us/sample - loss: 0.0302 - acc: 0.9927
# Epoch 497/500
# 274/274 [==============================] - 0s 215us/sample - loss: 0.0615 - acc: 0.9818
# Epoch 498/500
# 274/274 [==============================] - 0s 204us/sample - loss: 0.0257 - acc: 0.9891
# Epoch 499/500
# 274/274 [==============================] - 0s 213us/sample - loss: 0.0392 - acc: 0.9854
# Epoch 500/500
# 274/274 [==============================] - 0s 227us/sample - loss: 0.0492 - acc: 0.9854

# %%
from sklearn.metrics import roc_curve
y_pred_keras = model1.predict(test_x).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(test_y, y_pred_keras)

from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rfc, tpr_rfc, label='Random Forest (area = {:.3f})'.format(auc_rfc))
plt.plot(fpr_abc, tpr_abc, label='Adaboost (area = {:.3f})'.format(auc_abc))
plt.plot(fpr_gbc, tpr_gbc, label='Gradient Boost (area = {:.3f})'.format(auc_gbc))
plt.plot(fpr_xgb, tpr_xgb, label='XGBoost (area={:.3f})'.format(auc_xgb))
plt.plot(fpr_keras, tpr_keras, label='DNN (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('IRIS validation AUC using 16 features')
plt.legend(loc='best')
plt.savefig('./IRIS validation AUC using 16 features', dpi=500, bbox_inches = 'tight')

# %% [markdown]
# # test set

# %%
test_set = pd.read_csv("./IRIS_test_data_feature16.csv")
test_set
# Out:
#         SampleID      APOE    CR     EOTAXIN       FASL  genus_Coprococcus  \
# 0   ZJXC41N.1011  4.493446  1.20   53.844772  22.842338           0.006155
# 1     ZJXC41N.11  4.676616  1.14   34.774749   7.312334           0.004384
# 2     ZK112BX.06  4.498274  0.80   16.364588  23.399469           0.009931
# 3   ZK112BX.2002  4.658561  0.70   22.699267  36.770594           0.003895
# 4   ZKFV71L.6021  6.317280  0.78   57.453092  21.344060           0.019458
# ..           ...       ...   ...         ...        ...                ...
# 80  ZX52KVK.6021  3.733684  0.70   75.743014  29.043511           0.000625
# 81  ZY1ZKJY.2012  5.526337  0.80   77.288790  41.331150           0.004677
# 82  ZY1ZKJY.2014  5.544801  0.90   92.746548  25.692336           0.002760
# 83    ZY9XQJP.06  4.476238  0.70   81.689265  62.008463           0.005166
# 84    ZYXQKWY.04  5.054636  0.60  105.632147  27.507021           0.004714
#
#         GMCSF  HDL      IGHM       IL7.x       LEPTIN        MCP1    MCV  \
# 0   76.205530   49  5.876318  130.785507  6524.928521  512.424037   87.4
# 1   64.626523   66  6.040906   63.103091  8287.130338  400.446137   89.4
# 2   23.285023   48  5.692875   30.773060  2639.714672  145.609603   90.0
# 3   23.285023   53  6.227691   37.916807  1303.454801  157.786015   89.7
# 4   81.871313   83  3.168386   45.344634  7268.191787  871.352240   90.1
# ..        ...  ...       ...         ...          ...         ...    ...
# 80  43.730312   54  4.527109   79.607103  4338.509761  484.581299   91.0
# 81  59.348281   58  6.196430  136.268629  5789.050806  671.190247   86.7
# 82  46.333307   60  5.409079   71.178116  5451.129213  860.809016   86.0
# 83  40.127258   68  3.734070  130.584840  1955.885785  802.573426  101.9
# 84  85.910201   60  5.232720   95.310505  8538.055656  718.996861   94.0
#
#     MONOAB        SCF   SSPG  SSPG_classification  TGL       LPA
# 0     0.28  59.785643   75.0                    0   26  1.259847
# 1     0.20  58.214457   75.0                    0   49  2.421501
# 2     0.32  38.967428  234.0                    1  128  1.454972
# 3     0.24  55.515240  234.0                    1   67  1.352161
# 4     0.25  88.053678   65.0                    0   73 -2.561154
# ..     ...        ...    ...                  ...  ...       ...
# 80    0.32  60.941081  188.0                    1   82 -0.090156
# 81    0.72  94.595111  119.0                    0  187 -0.117142
# 82    0.63  93.685543  119.0                    0  133  0.821560
# 83    0.55  68.523684  151.0                    1   78 -3.105165
# 84    0.60  63.015421  158.5                    1  138 -0.781764
#
# [85 rows x 19 columns]

# %%
test_value= test_set.drop(["SampleID", "SSPG_classification","SSPG"],axis=1)
test_interest = test_set.SSPG_classification

print("Information of Training Data")
print("Samples : {}".format(value.shape[0]))
print("Features : {}".format(value.shape[1]))
# Out:
# Information of Training Data
# Samples : 343
# Features : 16

# %%
xx = np.array(test_value)
test_X_MinMax = min_max_scaler.fit_transform(xx)

# %%
# Test score
randomforest_pred = rfc.predict(test_X_MinMax)
adaboost_pred = abc.predict(test_X_MinMax)
gradient_pred = gbc.predict(test_X_MinMax)
xgb_pred=xgb_clf.predict(test_X_MinMax)
# DNN model predict values
DNN_predict = model1.predict_classes(test_X_MinMax)

# %%
# Random forest
y_pred_rfc2 = rfc.predict_proba(test_X_MinMax)[:,1]
fpr_rfc2, tpr_rfc2, thresholds_rfc2 = roc_curve(test_interest, y_pred_rfc2)
auc_rfc2 = auc(fpr_rfc2, tpr_rfc2)

# adaboost
y_pred_abc2 = abc.predict_proba(test_X_MinMax)[:,1]
fpr_abc2, tpr_abc2, thresholds_abc2 = roc_curve(test_interest, y_pred_abc2)
auc_abc2 = auc(fpr_abc2, tpr_abc2)

# Gradient Boost
y_pred_gbc2 = gbc.predict_proba(test_X_MinMax)[:,1]
fpr_gbc2, tpr_gbc2, thresholds_gbc2 = roc_curve(test_interest, y_pred_gbc2)
auc_gbc2 = auc(fpr_gbc2, tpr_gbc2)

# XGboost
y_pred_xgb2 = xgb_clf.predict_proba(test_X_MinMax)[:,1]
fpr_xgb2, tpr_xgb2, thresholds_xgb2 = roc_curve(test_interest, y_pred_xgb2)
auc_xgb2 = auc(fpr_xgb2, tpr_xgb2)


y_pred_keras2 = model1.predict(test_X_MinMax).ravel()
fpr_keras2, tpr_keras2, thresholds_keras2 = roc_curve(test_interest, y_pred_keras2)
auc_keras2 = auc(fpr_keras2, tpr_keras2)

plt.figure(2)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rfc2, tpr_rfc2, label='Random Forest (area = {:.3f})'.format(auc_rfc2))
plt.plot(fpr_abc2, tpr_abc2, label='Adaboost (area = {:.3f})'.format(auc_abc2))
plt.plot(fpr_gbc2, tpr_gbc2, label='Gradient Boost (area = {:.3f})'.format(auc_gbc2))
plt.plot(fpr_xgb2, tpr_xgb2, label='XGBoost (area={:.3f})'.format(auc_xgb2))
plt.plot(fpr_keras2, tpr_keras2, label='DNN (area = {:.3f})'.format(auc_keras2))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('IRIS test AUC using 16 features')
plt.legend(loc='best')
plt.savefig('./IRIS test AUC using 16 features', dpi=500, bbox_inches = 'tight')

# %%
model1.save("./feature_reduction_model_weights.h5")
